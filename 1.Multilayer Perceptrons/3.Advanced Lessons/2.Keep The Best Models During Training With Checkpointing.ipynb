# %% [markdown]
# # Keep The Best Models During Training With Checkpointing

# %% [markdown]
# Deep learning models can take hours, days, or even weeks to train, and if a training run is stopped unexpectedly, you can lose a lot of work. In this lesson, you will discover how you can checkpoint your deep learning models during training in Python using the Keras library. After completing this lesson, you will know:
#
# * The importance of checkpointing neural network models when training.
# * How to checkpoint each improvement to a model during training.
# * How to checkpoint the very best model observed during training.
#
# Let's get started.

# %% [markdown]
# ## Checkpointing Neural Network Models

# %% [markdown]
# Application checkpointing is a fault tolerance technique for long-running processes. It is an approach where a snapshot of the system's state is taken in case of system failure. If there is a problem, not all is lost. The checkpoint may be used directly or used as the starting point for a new run, picking up where it left off. When training deep learning models, the checkpoint captures the weights of the model. These weights can be used to make predictions as-is or used as the basis for ongoing training.
#
# The Keras library provides a checkpointing capability by a callback API. The `ModelCheckpoint` callback class allows you to define where to checkpoint the model weights, how the file should be named and under what circumstances to make a checkpoint of the model. The API allows you to specify which metric to monitor, such as loss or accuracy on the training or validation dataset. You can specify whether to look for an improvement in maximizing or minimizing the score. Finally, the filename that you use to store the weights can include variables like the epoch number or metric. The `ModelCheckpoint` instance can then be passed to the training process when calling the model's `fit()` function. Note, you may need to install the `h5py` library.

# %% [markdown]
# ## Checkpoint Neural Network Model Improvements

# %% [markdown]
# A good use of checkpointing is to output the model weights each time an improvement is observed during training. The example below creates a small neural network for the Pima Indians onset of diabetes binary classification problem. The example uses 33% of the data for validation.
#
# Checkpointing is set up to save the network weights only when there is improved classification accuracy on the validation dataset (`monitor='val acc'` and `mode='max'`). The weights are stored in a file that includes the score in the `filename weights-improvement-epoch-val acc=.2f.hdf5`.

# %%
import tensorflow as tf

# MLP for Pima Indians Dataset Serialize to JSON and HDF5
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint
import numpy

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# load pima indians dataset
dataset = numpy.loadtxt("../../datasets/pima-indians-diabetes.data.csv", delimiter=",")

# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# create model
model = Sequential()
model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# checkpoint
filepath="weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True,
mode='max')
callbacks_list = [checkpoint]

# %% [markdown]
# Running the example produces the output below. In the output, you can see cases where an improvement in the model accuracy on the validation dataset resulted in a new weight file being written to disk.

# %%
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10, callbacks=callbacks_list,
verbose=0)
# Out:
# Epoch 00001: val_accuracy improved from -inf to 0.67323, saving model to weights-improvement-01-0.67.hdf5
#
# Epoch 00002: val_accuracy did not improve from 0.67323
#
# Epoch 00003: val_accuracy did not improve from 0.67323
#
# Epoch 00004: val_accuracy improved from 0.67323 to 0.68504, saving model to weights-improvement-04-0.69.hdf5
#
# Epoch 00005: val_accuracy improved from 0.68504 to 0.68898, saving model to weights-improvement-05-0.69.hdf5
#
# Epoch 00006: val_accuracy did not improve from 0.68898
#
# Epoch 00007: val_accuracy did not improve from 0.68898
#
# Epoch 00008: val_accuracy did not improve from 0.68898
#
# Epoch 00009: val_accuracy did not improve from 0.68898
#
# Epoch 00010: val_accuracy did not improve from 0.68898
#
# Epoch 00011: val_accuracy did not improve from 0.68898
#
# Epoch 00012: val_accuracy did not improve from 0.68898
#
# Epoch 00013: val_accuracy did not improve from 0.68898
#
# Epoch 00014: val_accuracy improved from 0.68898 to 0.70472, saving model to weights-improvement-14-0.70.hdf5
#
# Epoch 00015: val_accuracy did not improve from 0.70472
#
# Epoch 00016: val_accuracy did not improve from 0.70472
#
# Epoch 00017: val_accuracy did not improve from 0.70472
#
# Epoch 00018: val_accuracy did not improve from 0.70472
#
# Epoch 00019: val_accuracy did not improve from 0.70472
#
# Epoch 00020: val_accuracy improved from 0.70472 to 0.70866, saving model to weights-improvement-20-0.71.hdf5
#
# Epoch 00021: val_accuracy did not improve from 0.70866
#
# Epoch 00022: val_accuracy did not improve from 0.70866
#
# Epoch 00023: val_accuracy did not improve from 0.70866
#
# Epoch 00024: val_accuracy did not improve from 0.70866
#
# Epoch 00025: val_accuracy did not improve from 0.70866
#
# Epoch 00026: val_accuracy did not improve from 0.70866
#
# Epoch 00027: val_accuracy did not improve from 0.70866
#
# Epoch 00028: val_accuracy did not improve from 0.70866
#
# Epoch 00029: val_accuracy did not improve from 0.70866
#
# Epoch 00030: val_accuracy did not improve from 0.70866
#
# Epoch 00031: val_accuracy did not improve from 0.70866
#
# Epoch 00032: val_accuracy did not improve from 0.70866
#
# Epoch 00033: val_accuracy did not improve from 0.70866
#
# Epoch 00034: val_accuracy did not improve from 0.70866
#
# Epoch 00035: val_accuracy did not improve from 0.70866
#
# Epoch 00036: val_accuracy did not improve from 0.70866
#
# Epoch 00037: val_accuracy did not improve from 0.70866
#
# Epoch 00038: val_accuracy did not improve from 0.70866
#
# Epoch 00039: val_accuracy did not improve from 0.70866
#
# Epoch 00040: val_accuracy did not improve from 0.70866
#
# Epoch 00041: val_accuracy improved from 0.70866 to 0.71260, saving model to weights-improvement-41-0.71.hdf5
#
# Epoch 00042: val_accuracy improved from 0.71260 to 0.71654, saving model to weights-improvement-42-0.72.hdf5
#
# Epoch 00043: val_accuracy did not improve from 0.71654
#
# Epoch 00044: val_accuracy did not improve from 0.71654
#
# Epoch 00045: val_accuracy improved from 0.71654 to 0.72047, saving model to weights-improvement-45-0.72.hdf5
#
# Epoch 00046: val_accuracy did not improve from 0.72047
#
# Epoch 00047: val_accuracy did not improve from 0.72047
#
# Epoch 00048: val_accuracy did not improve from 0.72047
#
# Epoch 00049: val_accuracy did not improve from 0.72047
#
# Epoch 00050: val_accuracy did not improve from 0.72047
#
# Epoch 00051: val_accuracy did not improve from 0.72047
#
# Epoch 00052: val_accuracy did not improve from 0.72047
#
# Epoch 00053: val_accuracy did not improve from 0.72047
#
# Epoch 00054: val_accuracy did not improve from 0.72047
#
# Epoch 00055: val_accuracy did not improve from 0.72047
#
# Epoch 00056: val_accuracy improved from 0.72047 to 0.72835, saving model to weights-improvement-56-0.73.hdf5
#
# Epoch 00057: val_accuracy did not improve from 0.72835
#
# Epoch 00058: val_accuracy did not improve from 0.72835
#
# Epoch 00059: val_accuracy did not improve from 0.72835
#
# Epoch 00060: val_accuracy did not improve from 0.72835
#
# Epoch 00061: val_accuracy did not improve from 0.72835
#
# Epoch 00062: val_accuracy did not improve from 0.72835
#
# Epoch 00063: val_accuracy improved from 0.72835 to 0.73622, saving model to weights-improvement-63-0.74.hdf5
#
# Epoch 00064: val_accuracy did not improve from 0.73622
#
# Epoch 00065: val_accuracy did not improve from 0.73622
#
# Epoch 00066: val_accuracy did not improve from 0.73622
#
# Epoch 00067: val_accuracy did not improve from 0.73622
#
# Epoch 00068: val_accuracy did not improve from 0.73622
#
# Epoch 00069: val_accuracy did not improve from 0.73622
#
# Epoch 00070: val_accuracy did not improve from 0.73622
#
# Epoch 00071: val_accuracy did not improve from 0.73622
#
# Epoch 00072: val_accuracy did not improve from 0.73622
#
# Epoch 00073: val_accuracy did not improve from 0.73622
#
# Epoch 00074: val_accuracy did not improve from 0.73622
#
# Epoch 00075: val_accuracy did not improve from 0.73622
#
# Epoch 00076: val_accuracy did not improve from 0.73622
#
# Epoch 00077: val_accuracy did not improve from 0.73622
#
# Epoch 00078: val_accuracy did not improve from 0.73622
#
# Epoch 00079: val_accuracy did not improve from 0.73622
#
# Epoch 00080: val_accuracy did not improve from 0.73622
#
# Epoch 00081: val_accuracy did not improve from 0.73622
#
# Epoch 00082: val_accuracy did not improve from 0.73622
#
# Epoch 00083: val_accuracy did not improve from 0.73622
#
# Epoch 00084: val_accuracy did not improve from 0.73622
#
# Epoch 00085: val_accuracy did not improve from 0.73622
#
# Epoch 00086: val_accuracy did not improve from 0.73622
#
# Epoch 00087: val_accuracy did not improve from 0.73622
#
# Epoch 00088: val_accuracy did not improve from 0.73622
#
# Epoch 00089: val_accuracy did not improve from 0.73622
#
# Epoch 00090: val_accuracy did not improve from 0.73622
#
# Epoch 00091: val_accuracy did not improve from 0.73622
#
# Epoch 00092: val_accuracy did not improve from 0.73622
#
# Epoch 00093: val_accuracy did not improve from 0.73622
#
# Epoch 00094: val_accuracy improved from 0.73622 to 0.74016, saving model to weights-improvement-94-0.74.hdf5
#
# Epoch 00095: val_accuracy did not improve from 0.74016
#
# Epoch 00096: val_accuracy did not improve from 0.74016
#
# Epoch 00097: val_accuracy did not improve from 0.74016
#
# Epoch 00098: val_accuracy did not improve from 0.74016
#
# Epoch 00099: val_accuracy did not improve from 0.74016
#
# Epoch 00100: val_accuracy did not improve from 0.74016
#
# Epoch 00101: val_accuracy did not improve from 0.74016
#
# Epoch 00102: val_accuracy did not improve from 0.74016
#
# Epoch 00103: val_accuracy did not improve from 0.74016
#
# Epoch 00104: val_accuracy improved from 0.74016 to 0.74803, saving model to weights-improvement-104-0.75.hdf5
#
# Epoch 00105: val_accuracy did not improve from 0.74803
#
# Epoch 00106: val_accuracy did not improve from 0.74803
#
# Epoch 00107: val_accuracy did not improve from 0.74803
#
# Epoch 00108: val_accuracy did not improve from 0.74803
#
# Epoch 00109: val_accuracy did not improve from 0.74803
#
# Epoch 00110: val_accuracy did not improve from 0.74803
#
# Epoch 00111: val_accuracy improved from 0.74803 to 0.75197, saving model to weights-improvement-111-0.75.hdf5
#
# Epoch 00112: val_accuracy did not improve from 0.75197
#
# Epoch 00113: val_accuracy did not improve from 0.75197
#
# Epoch 00114: val_accuracy did not improve from 0.75197
#
# Epoch 00115: val_accuracy did not improve from 0.75197
#
# Epoch 00116: val_accuracy did not improve from 0.75197
#
# Epoch 00117: val_accuracy did not improve from 0.75197
#
# Epoch 00118: val_accuracy did not improve from 0.75197
#
# Epoch 00119: val_accuracy did not improve from 0.75197
#
# Epoch 00120: val_accuracy improved from 0.75197 to 0.75591, saving model to weights-improvement-120-0.76.hdf5
#
# Epoch 00121: val_accuracy did not improve from 0.75591
#
# Epoch 00122: val_accuracy did not improve from 0.75591
#
# Epoch 00123: val_accuracy did not improve from 0.75591
#
# Epoch 00124: val_accuracy did not improve from 0.75591
#
# Epoch 00125: val_accuracy improved from 0.75591 to 0.75984, saving model to weights-improvement-125-0.76.hdf5
#
# Epoch 00126: val_accuracy did not improve from 0.75984
#
# Epoch 00127: val_accuracy did not improve from 0.75984
#
# Epoch 00128: val_accuracy did not improve from 0.75984
#
# Epoch 00129: val_accuracy did not improve from 0.75984
#
# Epoch 00130: val_accuracy did not improve from 0.75984
#
# Epoch 00131: val_accuracy did not improve from 0.75984
#
# Epoch 00132: val_accuracy did not improve from 0.75984
#
# Epoch 00133: val_accuracy improved from 0.75984 to 0.76378, saving model to weights-improvement-133-0.76.hdf5
# Epoch 00134: val_accuracy did not improve from 0.76378
#
# Epoch 00135: val_accuracy did not improve from 0.76378
#
# Epoch 00136: val_accuracy did not improve from 0.76378
#
# Epoch 00137: val_accuracy did not improve from 0.76378
#
# Epoch 00138: val_accuracy did not improve from 0.76378
#
# Epoch 00139: val_accuracy did not improve from 0.76378
#
# Epoch 00140: val_accuracy improved from 0.76378 to 0.76772, saving model to weights-improvement-140-0.77.hdf5
#
# Epoch 00141: val_accuracy did not improve from 0.76772
#
# Epoch 00142: val_accuracy did not improve from 0.76772
#
# Epoch 00143: val_accuracy did not improve from 0.76772
#
# Epoch 00144: val_accuracy did not improve from 0.76772
#
# Epoch 00145: val_accuracy did not improve from 0.76772
#
# Epoch 00146: val_accuracy did not improve from 0.76772
#
# Epoch 00147: val_accuracy improved from 0.76772 to 0.77165, saving model to weights-improvement-147-0.77.hdf5
#
# Epoch 00148: val_accuracy did not improve from 0.77165
#
# Epoch 00149: val_accuracy did not improve from 0.77165
#
# Epoch 00150: val_accuracy did not improve from 0.77165

# %% [markdown]
# You will also see a number of files in your working directory containing the network weights in HDF5 format. For example:
#
# ```
# ...
# weights-improvement-51-0.69.hdf5
# weights-improvement-56-0.73.hdf5
# weights-improvement-63-0.74.hdf5
# weights-improvement-67-0.71.hdf5
# weights-improvement-94-0.74.hdf5
# ```

# %% [markdown]
# This is a straightforward checkpointing strategy. It may create many unnecessary checkpoint files if the validation accuracy moves up and down over training epochs. Nevertheless, it will ensure that you have a snapshot of the best model discovered during your run.

# %% [markdown]
# ## Checkpoint Best Neural Network Model Only

# %% [markdown]
# A simpler checkpoint strategy is to save the model weights to the same file, if and only if the validation accuracy improves. This can be done quickly using the same code from above and changing the output filename to be fixed (not include score or epoch information). In this case, model weights are written to the file `weights.best.hdf5` only if the classification accuracy of the model on the validation dataset improves over the best seen so far.

# %%
import tensorflow as tf

# MLP for Pima Indians Dataset Serialize to JSON and HDF5
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint

import numpy

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# load pima indians dataset
dataset = numpy.loadtxt("../../datasets/pima-indians-diabetes.data.csv", delimiter=",")

# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# create model
model = Sequential()
model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# checkpoint
filepath="weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True,
mode='max')
callbacks_list = [checkpoint]

# %% [markdown]
# Running this example provides the following output (truncated for brevity):

# %%
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10, callbacks=callbacks_list,
verbose=0)
# Out:
# Epoch 00001: val_accuracy improved from -inf to 0.67323, saving model to weights.best.hdf5
#
# Epoch 00002: val_accuracy did not improve from 0.67323
#
# Epoch 00003: val_accuracy did not improve from 0.67323
#
# Epoch 00004: val_accuracy did not improve from 0.67323
#
# Epoch 00005: val_accuracy did not improve from 0.67323
#
# Epoch 00006: val_accuracy did not improve from 0.67323
#
# Epoch 00007: val_accuracy did not improve from 0.67323
#
# Epoch 00008: val_accuracy did not improve from 0.67323
#
# Epoch 00009: val_accuracy did not improve from 0.67323
#
# Epoch 00010: val_accuracy did not improve from 0.67323
#
# Epoch 00011: val_accuracy did not improve from 0.67323
#
# Epoch 00012: val_accuracy did not improve from 0.67323
#
# Epoch 00013: val_accuracy did not improve from 0.67323
#
# Epoch 00014: val_accuracy did not improve from 0.67323
#
# Epoch 00015: val_accuracy did not improve from 0.67323
#
# Epoch 00016: val_accuracy did not improve from 0.67323
#
# Epoch 00017: val_accuracy did not improve from 0.67323
#
# Epoch 00018: val_accuracy did not improve from 0.67323
#
# Epoch 00019: val_accuracy did not improve from 0.67323
#
# Epoch 00020: val_accuracy did not improve from 0.67323
#
# Epoch 00021: val_accuracy did not improve from 0.67323
#
# Epoch 00022: val_accuracy did not improve from 0.67323
#
# Epoch 00023: val_accuracy did not improve from 0.67323
#
# Epoch 00024: val_accuracy did not improve from 0.67323
#
# Epoch 00025: val_accuracy did not improve from 0.67323
#
# Epoch 00026: val_accuracy did not improve from 0.67323
#
# Epoch 00027: val_accuracy did not improve from 0.67323
#
# Epoch 00028: val_accuracy did not improve from 0.67323
#
# Epoch 00029: val_accuracy did not improve from 0.67323
#
# Epoch 00030: val_accuracy did not improve from 0.67323
#
# Epoch 00031: val_accuracy did not improve from 0.67323
#
# Epoch 00032: val_accuracy did not improve from 0.67323
#
# Epoch 00033: val_accuracy did not improve from 0.67323
#
# Epoch 00034: val_accuracy did not improve from 0.67323
#
# Epoch 00035: val_accuracy did not improve from 0.67323
#
# Epoch 00036: val_accuracy did not improve from 0.67323
#
# Epoch 00037: val_accuracy did not improve from 0.67323
#
# Epoch 00038: val_accuracy did not improve from 0.67323
#
# Epoch 00039: val_accuracy did not improve from 0.67323
#
# Epoch 00040: val_accuracy did not improve from 0.67323
#
# Epoch 00041: val_accuracy did not improve from 0.67323
#
# Epoch 00042: val_accuracy did not improve from 0.67323
#
# Epoch 00043: val_accuracy did not improve from 0.67323
#
# Epoch 00044: val_accuracy did not improve from 0.67323
#
# Epoch 00045: val_accuracy did not improve from 0.67323
#
# Epoch 00046: val_accuracy did not improve from 0.67323
#
# Epoch 00047: val_accuracy did not improve from 0.67323
#
# Epoch 00048: val_accuracy did not improve from 0.67323
#
# Epoch 00049: val_accuracy did not improve from 0.67323
#
# Epoch 00050: val_accuracy did not improve from 0.67323
#
# Epoch 00051: val_accuracy did not improve from 0.67323
#
# Epoch 00052: val_accuracy did not improve from 0.67323
#
# Epoch 00053: val_accuracy did not improve from 0.67323
#
# Epoch 00054: val_accuracy did not improve from 0.67323
#
# Epoch 00055: val_accuracy did not improve from 0.67323
#
# Epoch 00056: val_accuracy did not improve from 0.67323
#
# Epoch 00057: val_accuracy did not improve from 0.67323
#
# Epoch 00058: val_accuracy did not improve from 0.67323
#
# Epoch 00059: val_accuracy did not improve from 0.67323
#
# Epoch 00060: val_accuracy did not improve from 0.67323
#
# Epoch 00061: val_accuracy did not improve from 0.67323
#
# Epoch 00062: val_accuracy did not improve from 0.67323
#
# Epoch 00063: val_accuracy did not improve from 0.67323
#
# Epoch 00064: val_accuracy did not improve from 0.67323
#
# Epoch 00065: val_accuracy did not improve from 0.67323
#
# Epoch 00066: val_accuracy did not improve from 0.67323
#
# Epoch 00067: val_accuracy did not improve from 0.67323
#
# Epoch 00068: val_accuracy did not improve from 0.67323
#
# Epoch 00069: val_accuracy did not improve from 0.67323
#
# Epoch 00070: val_accuracy did not improve from 0.67323
#
# Epoch 00071: val_accuracy did not improve from 0.67323
#
# Epoch 00072: val_accuracy did not improve from 0.67323
#
# Epoch 00073: val_accuracy did not improve from 0.67323
#
# Epoch 00074: val_accuracy did not improve from 0.67323
#
# Epoch 00075: val_accuracy did not improve from 0.67323
#
# Epoch 00076: val_accuracy did not improve from 0.67323
#
# Epoch 00077: val_accuracy did not improve from 0.67323
#
# Epoch 00078: val_accuracy did not improve from 0.67323
#
# Epoch 00079: val_accuracy did not improve from 0.67323
#
# Epoch 00080: val_accuracy did not improve from 0.67323
#
# Epoch 00081: val_accuracy did not improve from 0.67323
#
# Epoch 00082: val_accuracy did not improve from 0.67323
#
# Epoch 00083: val_accuracy did not improve from 0.67323
#
# Epoch 00084: val_accuracy did not improve from 0.67323
#
# Epoch 00085: val_accuracy did not improve from 0.67323
#
# Epoch 00086: val_accuracy did not improve from 0.67323
#
# Epoch 00087: val_accuracy did not improve from 0.67323
#
# Epoch 00088: val_accuracy did not improve from 0.67323
#
# Epoch 00089: val_accuracy did not improve from 0.67323
#
# Epoch 00090: val_accuracy did not improve from 0.67323
#
# Epoch 00091: val_accuracy did not improve from 0.67323
#
# Epoch 00092: val_accuracy did not improve from 0.67323
#
# Epoch 00093: val_accuracy did not improve from 0.67323
#
# Epoch 00094: val_accuracy did not improve from 0.67323
#
# Epoch 00095: val_accuracy did not improve from 0.67323
#
# Epoch 00096: val_accuracy did not improve from 0.67323
#
# Epoch 00097: val_accuracy did not improve from 0.67323
#
# Epoch 00098: val_accuracy did not improve from 0.67323
#
# Epoch 00099: val_accuracy did not improve from 0.67323
#
# Epoch 00100: val_accuracy did not improve from 0.67323
#
# Epoch 00101: val_accuracy did not improve from 0.67323
#
# Epoch 00102: val_accuracy did not improve from 0.67323
#
# Epoch 00103: val_accuracy did not improve from 0.67323
#
# Epoch 00104: val_accuracy did not improve from 0.67323
#
# Epoch 00105: val_accuracy did not improve from 0.67323
#
# Epoch 00106: val_accuracy did not improve from 0.67323
#
# Epoch 00107: val_accuracy did not improve from 0.67323
#
# Epoch 00108: val_accuracy did not improve from 0.67323
#
# Epoch 00109: val_accuracy did not improve from 0.67323
#
# Epoch 00110: val_accuracy did not improve from 0.67323
#
# Epoch 00111: val_accuracy did not improve from 0.67323
#
# Epoch 00112: val_accuracy did not improve from 0.67323
#
# Epoch 00113: val_accuracy did not improve from 0.67323
#
# Epoch 00114: val_accuracy did not improve from 0.67323
#
# Epoch 00115: val_accuracy did not improve from 0.67323
#
# Epoch 00116: val_accuracy did not improve from 0.67323
#
# Epoch 00117: val_accuracy did not improve from 0.67323
#
# Epoch 00118: val_accuracy did not improve from 0.67323
#
# Epoch 00119: val_accuracy did not improve from 0.67323
#
# Epoch 00120: val_accuracy did not improve from 0.67323
#
# Epoch 00121: val_accuracy did not improve from 0.67323
#
# Epoch 00122: val_accuracy did not improve from 0.67323
#
# Epoch 00123: val_accuracy did not improve from 0.67323
#
# Epoch 00124: val_accuracy did not improve from 0.67323
#
# Epoch 00125: val_accuracy did not improve from 0.67323
#
# Epoch 00126: val_accuracy did not improve from 0.67323
#
# Epoch 00127: val_accuracy did not improve from 0.67323
#
# Epoch 00128: val_accuracy did not improve from 0.67323
#
# Epoch 00129: val_accuracy did not improve from 0.67323
#
# Epoch 00130: val_accuracy did not improve from 0.67323
#
# Epoch 00131: val_accuracy did not improve from 0.67323
#
# Epoch 00132: val_accuracy did not improve from 0.67323
#
# Epoch 00133: val_accuracy did not improve from 0.67323
#
# Epoch 00134: val_accuracy did not improve from 0.67323
#
# Epoch 00135: val_accuracy did not improve from 0.67323
#
# Epoch 00136: val_accuracy did not improve from 0.67323
#
# Epoch 00137: val_accuracy did not improve from 0.67323
#
# Epoch 00138: val_accuracy did not improve from 0.67323
#
# Epoch 00139: val_accuracy did not improve from 0.67323
#
# Epoch 00140: val_accuracy did not improve from 0.67323
#
# Epoch 00141: val_accuracy did not improve from 0.67323
#
# Epoch 00142: val_accuracy did not improve from 0.67323
#
# Epoch 00143: val_accuracy did not improve from 0.67323
#
# Epoch 00144: val_accuracy did not improve from 0.67323
#
# Epoch 00145: val_accuracy did not improve from 0.67323
#
# Epoch 00146: val_accuracy did not improve from 0.67323
#
# Epoch 00147: val_accuracy did not improve from 0.67323
#
# Epoch 00148: val_accuracy did not improve from 0.67323
# Epoch 00149: val_accuracy did not improve from 0.67323
#
# Epoch 00150: val_accuracy did not improve from 0.67323

# %% [markdown]
# You should see the weight file in your local directory.
#
# `weights.best.hdf5`

# %% [markdown]
# ## Loading a Saved Neural Network Model

# %% [markdown]
# Now that you have seen how to checkpoint your deep learning models during training, you need to review how to load and use a checkpointed model. The checkpoint only includes the model weights. It assumes you know the network structure. This too can be serialized to file in JSON or YAML format. In the example below, the model structure is known, and the best weights are loaded from the previous experiment, stored in the working directory in the `weights.best.hdf5` file. The model is then used to make predictions on the entire dataset.

# %%
import tensorflow as tf

# MLP for Pima Indians Dataset Serialize to JSON and HDF5
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import numpy

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# create model
model = Sequential()
model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

# load weights
model.load_weights("weights.best.hdf5")

# Compile model (required to make predictions)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print("Created model and loaded weights from file")

# load pima indians dataset
dataset = numpy.loadtxt("../../datasets/pima-indians-diabetes.data.csv", delimiter=",")

# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# Out:
# Created model and loaded weights from file

# %% [markdown]
# Running the example produces the following output:

# %%
# estimate accuracy on whole dataset using loaded weights
scores = model.evaluate(X, Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 65.10%

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lesson, you have discovered the importance of checkpointing deep learning models for long training runs. You learned:
#
# * How to use Keras to checkpoint each time an improvement to the model is observed.
# * How to only checkpoint the very best model observed during training.
# * How to load a checkpointed model from a file and use it later to make predictions.

# %% [markdown]
# ### Next

# %% [markdown]
# You now know how to checkpoint your deep learning models in Keras during long training schemes. In the next lesson, you will discover how to collect, inspect, and plot metrics collected about your model during training.
