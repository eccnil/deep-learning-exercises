# %% [markdown]
# <a href="https://colab.research.google.com/github/Deep-Learning-Challenge/challenge-notebooks/blob/master/1.Multilayer%20Perceptrons/1.Lessons/2.Evaluate%20The%20Performance%20of%20Deep%20Learning%20Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" /></a>

# %% [markdown]
# # Evaluate The Performance of Deep Learning Models

# %% [markdown]
# There are many decisions to make when designing and configuring your deep learning models. Most of these decisions must be resolved empirically through trial and error and evaluating them on real data. As such, it is critically important to have a robust way to evaluate the performance of your neural network and deep learning models. In this lesson, you will discover a few ways that you can use to evaluate model performance using Keras. After completing this lesson, you will know:
#
# * How to evaluate a Keras model using an automatic verification dataset.
# * How to evaluate a Keras model using a manual verification dataset.
# * How to evaluate a Keras model using k-fold cross-validation.
#
# Let's get started.

# %% [markdown]
# ## Runtime Setup

# %%
import sys

dataset_name = "pima-indians-diabetes.data.csv"
if 'google.colab' in sys.modules:
    DATASET = f"https://github.com/Deep-Learning-Challenge/challenge-notebooks/raw/master/datasets/{dataset_name}"
else:
    DATASET = f"../../datasets/{dataset_name}"
    
DATASET
# Out:
# '../../datasets/pima-indians-diabetes.data.csv'

# %% [markdown]
# ## Empirically Evaluate Network Configurations

# %% [markdown]
# There is a myriad of decisions you must make when designing and configuring your deep learning models. Many of these decisions can be resolved by copying the structure of other people's networks and using heuristics. Ultimately, the best technique is to actually design small experiments and empirically evaluate options using real data. This includes high-level decisions like the number, size, and type of layers in your network. It also consists of the lower level decisions like the choice of the loss function, activation functions, optimization procedure, and the number of epochs.
#
# Deep learning is often used on problems that have very large datasets. That is tens of thousands or hundreds of thousands of instances. As such, you need to have a robust test harness that allows you to estimate a given configuration's performance on unseen data and reliably compare the performance to other configurations.

# %% [markdown]
# ## Data Splitting

# %% [markdown]
# A large amount of data and the complexity of the models require very long training times. It is typical to use a simple separation of data into training and test datasets or training and validation datasets. Keras provides two convenient ways of evaluating your deep learning
# algorithms this way:
#
# 1. Use an automatic verification dataset.
# 2. Use a manual verification dataset.

# %% [markdown]
# ### Use an Automatic Verification Dataset

# %% [markdown]
# Keras can separate a portion of your training data into a validation dataset and evaluate your model's performance on that validation dataset each epoch. You can do this by setting the `validation_split` argument on the `fit()` function to a percentage of your training dataset size. For example, a reasonable value might be 0.2 or 0.33 for 20% or 33% of your training
# data held back for validation. The example below demonstrates using an automatic validation dataset on the Pima Indians onset of diabetes dataset.

# %%
# MLP with automatic validation set
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy

# fix random seed for reproducibility
numpy.random.seed(7)

# load pima indians dataset
dataset = numpy.loadtxt(DATASET, delimiter=",")

# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# create model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# 2021-10-04 21:42:35.318848: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-10-04 21:42:35.318902: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-10-04 21:42:37.747026: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-10-04 21:42:37.747091: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-10-04 21:42:37.747113: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (a03532bba26e): /proc/driver/nvidia/version does not exist
# 2021-10-04 21:42:37.747765: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Running the example, you can see that each epoch's verbose output shows the loss and accuracy of both the training dataset and the validation dataset.

# %%
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10)
# Out:
# 2021-10-04 21:42:40.690039: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1
150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5288 - accuracy: 0.7451 - val_loss: 0.6171 - val_accuracy: 0.6890
# Epoch 136/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5406 - accuracy: 0.7490 - val_loss: 0.5800 - val_accuracy: 0.7126
# Epoch 137/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5664 - accuracy: 0.7101 - val_loss: 0.5918 - val_accuracy: 0.6929
# Epoch 138/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5310 - accuracy: 0.7471 - val_loss: 0.5820 - val_accuracy: 0.7205
# Epoch 139/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5444 - accuracy: 0.7354 - val_loss: 0.5849 - val_accuracy: 0.7047
# Epoch 140/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5227 - accuracy: 0.7354 - val_loss: 0.5933 - val_accuracy: 0.7165
# Epoch 141/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5393 - accuracy: 0.7354 - val_loss: 0.6213 - val_accuracy: 0.6929
# Epoch 142/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5362 - accuracy: 0.7471 - val_loss: 0.5997 - val_accuracy: 0.7087
# Epoch 143/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5324 - accuracy: 0.7276 - val_loss: 0.6201 - val_accuracy: 0.6850
# Epoch 144/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5984 - accuracy: 0.7160 - val_loss: 0.5882 - val_accuracy: 0.7126
# Epoch 145/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5427 - accuracy: 0.7354 - val_loss: 0.5820 - val_accuracy: 0.7087
# Epoch 146/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5591 - accuracy: 0.7121 - val_loss: 0.6139 - val_accuracy: 0.7047
# Epoch 147/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5324 - accuracy: 0.7471 - val_loss: 0.6494 - val_accuracy: 0.6654
# Epoch 148/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5341 - accuracy: 0.7393 - val_loss: 0.6323 - val_accuracy: 0.7047
# Epoch 149/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5364 - accuracy: 0.7374 - val_loss: 0.5840 - val_accuracy: 0.7165
# Epoch 150/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5240 - accuracy: 0.7568 - val_loss: 0.6166 - val_accuracy: 0.7087

# %% [markdown]
# ### Use a Manual Verification Dataset

# %% [markdown]
# Keras also allows you to manually specify the dataset to use for validation during training. In this example we use the handy `train_test_split()` function from the Python scikit-learn machine learning library to separate our data into a training and test dataset. We use 67% for training and the remaining 33% of the data for validation. The validation dataset can be specified to the `fit()` function in Keras by the `validation_data` argument. It takes a tuple of
# the input and output datasets.

# %%
# MLP with automatic validation set
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow. keras.layers import Dense
from sklearn.model_selection import train_test_split
import numpy

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# load pima indians dataset
dataset = numpy.loadtxt(DATASET, delimiter=",")

# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# split into 67% for train and 33% for test
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=seed)

# create model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# Like before, running the example provides a verbose output of training that includes the loss and accuracy of the model on both the training and validation datasets for each epoch.

# %%
# Fit the model
model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 52/52 [==============================] - 1s 4ms/step - loss: 4.5936 - accuracy: 0.6654 - val_loss: 1.8701 - val_accuracy: 0.6181
# Epoch 2/150
# 52/52 [==============================] - 0s 2ms/step - loss: 1.3028 - accuracy: 0.6615 - val_loss: 1.1247 - val_accuracy: 0.6378
# Epoch 3/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.8821 - accuracy: 0.6693 - val_loss: 0.8525 - val_accuracy: 0.6339
# Epoch 4/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.7554 - accuracy: 0.6887 - val_loss: 0.7670 - val_accuracy: 0.6299
# Epoch 5/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.7204 - accuracy: 0.6790 - val_loss: 0.7280 - val_accuracy: 0.6181
# Epoch 6/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6915 - accuracy: 0.6751 - val_loss: 0.7220 - val_accuracy: 0.5984
# Epoch 7/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6888 - accuracy: 0.6770 - val_loss: 0.7023 - val_accuracy: 0.6142
# Epoch 8/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6754 - accuracy: 0.6751 - val_loss: 0.7030 - val_accuracy: 0.6181
# Epoch 9/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6761 - accuracy: 0.6887 - val_loss: 0.7007 - val_accuracy: 0.6142
# Epoch 10/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6742 - accuracy: 0.6809 - val_loss: 0.6923 - val_accuracy: 0.6102
# Epoch 11/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6624 - accuracy: 0
150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5616 - accuracy: 0.7043 - val_loss: 0.6047 - val_accuracy: 0.6811
# Epoch 75/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5698 - accuracy: 0.7160 - val_loss: 0.6159 - val_accuracy: 0.6811
# Epoch 76/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5605 - accuracy: 0.7121 - val_loss: 0.5969 - val_accuracy: 0.6929
# Epoch 77/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5584 - accuracy: 0.7179 - val_loss: 0.5953 - val_accuracy: 0.6850
# Epoch 78/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5747 - accuracy: 0.7160 - val_loss: 0.6607 - val_accuracy: 0.6811
# Epoch 79/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5606 - accuracy: 0.7179 - val_loss: 0.5856 - val_accuracy: 0.6850
# Epoch 80/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5545 - accuracy: 0.7043 - val_loss: 0.5790 - val_accuracy: 0.7087
# Epoch 81/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5528 - accuracy: 0.7276 - val_loss: 0.5896 - val_accuracy: 0.7008
# Epoch 82/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5524 - accuracy: 0.7218 - val_loss: 0.5804 - val_accuracy: 0.7008
# Epoch 83/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5546 - accuracy: 0.7257 - val_loss: 0.5887 - val_accuracy: 0.6929
# Epoch 84/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5462 - accuracy: 0.7276 - val_loss: 0.5956 - val_accuracy: 0.6732
# Epoch 85/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5601 - accuracy: 0.7276 - val_loss: 0.5751 - val_accuracy: 0.6969
# Epoch 86/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5480 - accuracy: 0.7354 - val_loss: 0.5763 - val_accuracy: 0.7008
# Epoch 87/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5443 - accuracy: 0.7412 - val_loss: 0.5765 - val_accuracy: 0.7008
# Epoch 88/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5432 - accuracy: 0.7412 - val_loss: 0.5746 - val_accuracy: 0.6811
# Epoch 89/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5504 - accuracy: 0.7218 - val_loss: 0.5764 - val_accuracy: 0.7008
# Epoch 90/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5414 - accuracy: 0.7393 - val_loss: 0.5711 - val_accuracy: 0.7008
# Epoch 91/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5470 - accuracy: 0.7354 - val_loss: 0.5854 - val_accuracy: 0.6693
# Epoch 92/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5399 - accuracy: 0.7490 - val_loss: 0.5652 - val_accuracy: 0.7165
# Epoch 93/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5431 - accuracy: 0.7374 - val_loss: 0.5654 - val_accuracy: 0.7126
# Epoch 94/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5404 - accuracy: 0.7276 - val_loss: 0.5732 - val_accuracy: 0.7008
# Epoch 95/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5461 - accuracy: 0.7432 - val_loss: 0.5716 - val_accuracy: 0.6969
# Epoch 96/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5451 - accuracy: 0.7412 - val_loss: 0.5663 - val_accuracy: 0.6890
# Epoch 97/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5448 - accuracy: 0.7354 - val_loss: 0.5692 - val_accuracy: 0.6929
# Epoch 98/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5364 - accuracy: 0.7451 - val_loss: 0.5607 - val_accuracy: 0.7165
# Epoch 99/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5394 - accuracy: 0.7354 - val_loss: 0.5657 - val_accuracy: 0.7047
# Epoch 100/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5357 - accuracy: 0.7451 - val_loss: 0.6077 - val_accuracy: 0.6929
# Epoch 101/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5532 - accuracy: 0.7335 - val_loss: 0.5657 - val_accuracy: 0.6969
# Epoch 102/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5353 - accuracy: 0.7490 - val_loss: 0.5595 - val_accuracy: 0.7126
# Epoch 103/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5311 - accuracy: 0.7393 - val_loss: 0.5619 - val_accuracy: 0.7087
# Epoch 104/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5374 - accuracy: 0.7432 - val_loss: 0.5657 - val_accuracy: 0.7047
# Epoch 105/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5357 - accuracy: 0.7276 - val_loss: 0.5588 - val_accuracy: 0.7244
# Epoch 106/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5306 - accuracy: 0.7549 - val_loss: 0.5602 - val_accuracy: 0.7165
# Epoch 107/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5316 - accuracy: 0.7354 - val_loss: 0.5533 - val_accuracy: 0.7165
# Epoch 108/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5294 - accuracy: 0.7374 - val_loss: 0.5653 - val_accuracy: 0.6850
# Epoch 109/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5282 - accuracy: 0.7296 - val_loss: 0.5583 - val_accuracy: 0.7165
# Epoch 110/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5275 - accuracy: 0.7626 - val_loss: 0.5689 - val_accuracy: 0.7126
# Epoch 111/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5357 - accuracy: 0.7471 - val_loss: 0.5547 - val_accuracy: 0.7205
# Epoch 112/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5281 - accuracy: 0.7315 - val_loss: 0.5644 - val_accuracy: 0.7205
# Epoch 113/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5314 - accuracy: 0.7588 - val_loss: 0.5680 - val_accuracy: 0.6969
# Epoch 114/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5245 - accuracy: 0.7529 - val_loss: 0.5530 - val_accuracy: 0.7244
# Epoch 115/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5329 - accuracy: 0.7315 - val_loss: 0.5473 - val_accuracy: 0.7165
# Epoch 116/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5358 - accuracy: 0.7412 - val_loss: 0.5685 - val_accuracy: 0.7087
# Epoch 117/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5290 - accuracy: 0.7529 - val_loss: 0.5631 - val_accuracy: 0.7047
# Epoch 118/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5284 - accuracy: 0.7510 - val_loss: 0.5515 - val_accuracy: 0.7126
# Epoch 119/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5188 - accuracy: 0.7529 - val_loss: 0.5484 - val_accuracy: 0.7165
# Epoch 120/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5294 - accuracy: 0.7451 - val_loss: 0.5494 - val_accuracy: 0.7205
# Epoch 121/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5191 - accuracy: 0.7510 - val_loss: 0.5480 - val_accuracy: 0.7205
# Epoch 122/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5256 - accuracy: 0.7529 - val_loss: 0.5451 - val_accuracy: 0.7205
# Epoch 123/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5253 - accuracy: 0.7451 - val_loss: 0.5427 - val_accuracy: 0.7244
# Epoch 124/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5196 - accuracy: 0.7588 - val_loss: 0.5432 - val_accuracy: 0.7205
# Epoch 125/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5142 - accuracy: 0.7646 - val_loss: 0.5398 - val_accuracy: 0.7402
# Epoch 126/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5169 - accuracy: 0.7665 - val_loss: 0.5551 - val_accuracy: 0.7087
# Epoch 127/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5240 - accuracy: 0.7451 - val_loss: 0.5379 - val_accuracy: 0.7283
# Epoch 128/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5192 - accuracy: 0.7724 - val_loss: 0.5501 - val_accuracy: 0.7165
# Epoch 129/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5173 - accuracy: 0.7412 - val_loss: 0.5547 - val_accuracy: 0.7323
# Epoch 130/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5173 - accuracy: 0.7412 - val_loss: 0.5373 - val_accuracy: 0.7323
# Epoch 131/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5162 - accuracy: 0.7432 - val_loss: 0.5388 - val_accuracy: 0.7283
# Epoch 132/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5153 - accuracy: 0.7588 - val_loss: 0.5437 - val_accuracy: 0.7283
# Epoch 133/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5163 - accuracy: 0.7568 - val_loss: 0.5377 - val_accuracy: 0.7362
# Epoch 134/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5143 - accuracy: 0.7471 - val_loss: 0.5369 - val_accuracy: 0.7323
# Epoch 135/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5125 - accuracy: 0.7588 - val_loss: 0.5375 - val_accuracy: 0.7244
# Epoch 136/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5149 - accuracy: 0.7588 - val_loss: 0.5399 - val_accuracy: 0.7283
# Epoch 137/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5233 - accuracy: 0.7704 - val_loss: 0.5444 - val_accuracy: 0.7165
# Epoch 138/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5084 - accuracy: 0.7549 - val_loss: 0.5398 - val_accuracy: 0.7480
# Epoch 139/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5155 - accuracy: 0.7529 - val_loss: 0.5367 - val_accuracy: 0.7480
# Epoch 140/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5167 - accuracy: 0.7607 - val_loss: 0.5358 - val_accuracy: 0.7323
# Epoch 141/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5103 - accuracy: 0.7607 - val_loss: 0.5366 - val_accuracy: 0.7362
# Epoch 142/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5110 - accuracy: 0.7529 - val_loss: 0.5381 - val_accuracy: 0.7244
# Epoch 143/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5098 - accuracy: 0.7685 - val_loss: 0.5327 - val_accuracy: 0.7323
# Epoch 144/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5120 - accuracy: 0.7626 - val_loss: 0.5527 - val_accuracy: 0.7283
# Epoch 145/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5113 - accuracy: 0.7665 - val_loss: 0.5288 - val_accuracy: 0.7244
# Epoch 146/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5140 - accuracy: 0.7529 - val_loss: 0.5349 - val_accuracy: 0.7362
# Epoch 147/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5101 - accuracy: 0.7626 - val_loss: 0.5295 - val_accuracy: 0.7362
# Epoch 148/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5047 - accuracy: 0.7763 - val_loss: 0.5403 - val_accuracy: 0.7205
# Epoch 149/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5070 - accuracy: 0.7626 - val_loss: 0.5344 - val_accuracy: 0.7402
# Epoch 150/150
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5050 - accuracy: 0.7607 - val_loss: 0.5339 - val_accuracy: 0.7362

# %% [markdown]
# ## Manual k-Fold Cross-Validation

# %% [markdown]
# The gold standard for machine learning model evaluation is `k-fold cross-validation`. It provides a robust estimate of the performance of a model on unseen data. It does this by **splitting the training dataset into k subsets**, taking turns training models on all subsets except one held out, and evaluating model performance on the held-out validation dataset. The process is **repeated until all subsets are allowed to be the held-out** validation set. The performance measure is then averaged across all models that are created.
#
# Cross-validation is often not used for evaluating deep learning models because of the more significant computational expense. For example, k-fold cross-validation is often used with 5 or 10 folds. As such, 5 or 10 models must be constructed and evaluated, significantly adding to the evaluation time. Nevertheless, **when the problem is small enough** or if you have sufficient compute resources, k-fold cross-validation can give you a less biased estimate of the performance of your model.
#
# In the example below, we use the handy `StratifiedKFold` [class](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html) from the scikit-learn Python machine learning library to split the training dataset into ten folds. The **folds are stratified, meaning that the algorithm attempts to balance each class's** number of instances in each fold. The example creates and evaluates ten models using the ten splits of the data and collects all of the scores. The verbose output for each epoch is turned off by passing `verbose=0` to the `fit()` and `evaluate()` functions on the model. The performance is printed for each model, and it is stored. The average and standard deviation of the model performance is then printed at the end of the run to provide a robust estimate of model accuracy.

# %%
# MLP for Pima Indians Dataset with 10-fold cross validation
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

from tensorflow.keras.models import Sequential
from tensorflow. keras.layers import Dense

from sklearn.model_selection import StratifiedKFold
import numpy

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# load pima indians dataset
dataset = numpy.loadtxt(DATASET, delimiter=",")

# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# define 10-fold cross validation test harness
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
cvscores = []

for train, test in kfold.split(X, Y):
    # create model
    model = Sequential()
    model.add(Dense(12, input_dim=8, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

    # Fit the model
    model.fit(X[train], Y[train], epochs=150, batch_size=10, verbose=0)

    # evaluate the model
    scores = model.evaluate(X[test], Y[test], verbose=0)
    print(f"{model.metrics_names[1]}: {scores[1]*100:.2f}%")
    cvscores.append(scores[1] * 100)

print("%.2f%% (+/- %.2f%%)" % (numpy.mean(cvscores), numpy.std(cvscores)))

# %% [markdown]
# Notice that we had to re-create the model for each loop to fit and evaluate it with the fold data. In the next lesson, we will look at how we can use Keras models natively with the scikit-learn machine learning library.

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lesson, you discovered the importance of having a robust way to estimate your deep learning models' performance on unseen data. You learned three ways that you can evaluate the performance of your deep learning models in Python using the Keras library:
#
# * Automatically splitting a training dataset into train and validation datasets.
# * Manually and explicitly defining training and validation dataset.
# * Evaluating performance using k-fold cross-validation, the gold-standard technique.
