# %% [markdown]
# <a href="https://colab.research.google.com/github/Deep-Learning-Challenge/challenge-notebooks/blob/master/1.Multilayer%20Perceptrons/3.Advanced%20Lessons/2.Keep%20The%20Best%20Models%20During%20Training%20With%20Checkpointing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" /></a>

# %% [markdown]
# # Keep The Best Models During Training With Checkpointing

# %% [markdown]
# Deep learning models can take hours, days, or even weeks to train, and if a training run is stopped unexpectedly, you can lose a lot of work. In this lesson, you will discover how you can checkpoint your deep learning models during training in Python using the Keras library. After completing this lesson, you will know:
#
# * The importance of checkpointing neural network models when training.
# * How to checkpoint each improvement to a model during training.
# * How to checkpoint the very best model observed during training.
#
# Let's get started.

# %% [markdown]
# ## Runtime Setup

# %%
import sys

dataset_name = "pima-indians-diabetes.data.csv"
if 'google.colab' in sys.modules:
    DATASET = f"https://github.com/Deep-Learning-Challenge/challenge-notebooks/raw/master/datasets/{dataset_name}"
else:
    DATASET = f"../../datasets/{dataset_name}"
    
DATASET
# Out:
# '../../datasets/pima-indians-diabetes.data.csv'

# %% [markdown]
# ## Checkpointing Neural Network Models

# %% [markdown]
# Application checkpointing is a fault tolerance technique for long-running processes. It is an approach where a snapshot of the system's state is taken in case of system failure. If there is a problem, not all is lost. The checkpoint may be used directly or used as the starting point for a new run, picking up where it left off. When training deep learning models, the checkpoint captures the weights of the model. These weights can be used to make predictions as-is or used as the basis for ongoing training.
#
# The Keras library provides a checkpointing capability by a callback API. The `ModelCheckpoint` callback class allows you to define where to checkpoint the model weights, how the file should be named and under what circumstances to make a checkpoint of the model. The API allows you to specify which metric to monitor, such as loss or accuracy on the training or validation dataset. You can specify whether to look for an improvement in maximizing or minimizing the score. Finally, the filename that you use to store the weights can include variables like the epoch number or metric. The `ModelCheckpoint` instance can then be passed to the training process when calling the model's `fit()` function. Note, you may need to install the `h5py` library.

# %% [markdown]
# ## Checkpoint Neural Network Model Improvements

# %% [markdown]
# A good use of checkpointing is to output the model weights each time an improvement is observed during training. The example below creates a small neural network for the Pima Indians onset of diabetes binary classification problem. The example uses 33% of the data for validation.
#
# Checkpointing is set up to save the network weights only when there is improved classification accuracy on the validation dataset (`monitor='val acc'` and `mode='max'`). The weights are stored in a file that includes the score in the `filename weights-improvement-epoch-val acc=.2f.hdf5`.

# %%
import tensorflow as tf

# MLP for Pima Indians Dataset Serialize to JSON and HDF5
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint
import numpy

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# load pima indians dataset
dataset = numpy.loadtxt(DATASET, delimiter=",")

# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# create model
model = Sequential()
model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# 2021-10-17 10:47:49.605599: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-10-17 10:47:49.605723: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-10-17 10:47:58.709454: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-10-17 10:47:58.709537: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-10-17 10:47:58.709583: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (33d7dde1ac92): /proc/driver/nvidia/version does not exist
# 2021-10-17 10:47:58.709892: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# checkpoint
filepath="weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True,
mode='max')
callbacks_list = [checkpoint]

# %% [markdown]
# Running the example produces the output below. In the output, you can see cases where an improvement in the model accuracy on the validation dataset resulted in a new weight file being written to disk.

# %%
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10, callbacks=callbacks_list,
verbose=0)
# Out:
# 2021-10-17 10:50:04.061547: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 00001: val_accuracy improved from -inf to 0.67323, saving model to weights-improvement-01-0.67.hdf5
#
# Epoch 00002: val_accuracy did not improve from 0.67323
#
# Epoch 00003: val_accuracy did not improve from 0.67323
#
# Epoch 00004: val_accuracy improved from 0.67323 to 0.67717, saving model to weights-improvement-04-0.68.hdf5
#
# Epoch 00005: val_accuracy did not improve from 0.67717
#
# Epoch 00006: val_accuracy did not improve from 0.67717
#
# Epoch 00007: val_accuracy did not improve from 0.67717
#
# Epoch 00008: val_accuracy did not improve from 0.67717
#
# Epoch 00009: val_accuracy did not improve from 0.67717
#
# Epoch 00010: val_accuracy did not improve from 0.67717
#
# Epoch 00011: val_accuracy improved from 0.67717 to 0.69685, saving model to weights-improvement-11-0.70.hdf5
#
# Epoch 00012: val_accuracy did not improve from 0.69685
#
# Epoch 00013: val_accuracy improved from 0.69685 to 0.70079, saving model to weights-improvement-13-0.70.hdf5
#
# Epoch 00014: val_accuracy did not improve from 0.70079
#
# Epoch 00015: val_accuracy improved from 0.70079 to 0.71654, saving model to weights-improvement-15-0.72.hdf5
#
# Epoch 00016: val_accuracy did not improve from 0.71654
#
# Epoch 00017: val_accuracy did not improve from 0.71654
#
# Epoch 00018: val_accuracy did not improve from 0.71654
#
# Epoch 00019: val_accuracy did not improve from 0.71654
#
# Epoch 00020: val_accuracy did not improve from 0.71654
#
# Epoch 00021: val_accuracy did not improve from 0.71654
#
# Epoch 00022: val_accuracy did not improve from 0.71654
#
# Epoch 00023: val_accuracy did not improve from 0.71654
#
# Epoch 00024: val_accuracy did not improve from 0.71654
#
# Epoch 00025: val_accuracy did not improve from 0.71654
#
# Epoch 00026: val_accuracy did not improve from 0.71654
#
# Epoch 00027: val_accuracy did not improve from 0.71654
#
# Epoch 00028: val_accuracy improved from 0.71654 to 0.72441, saving model to weights-improvement-28-0.72.hdf5
#
# Epoch 00029: val_accuracy did not improve from 0.72441
#
# Epoch 00030: val_accuracy did not improve from 0.72441
#
# Epoch 00031: val_accuracy did not improve from 0.72441
#
# Epoch 00032: val_accuracy did not improve from 0.72441
#
# Epoch 00033: val_accuracy did not improve from 0.72441
#
# Epoch 00034: val_accuracy did not improve from 0.72441
#
# Epoch 00035: val_accuracy did not improve from 0.72441
#
# Epoch 00036: val_accuracy did not improve from 0.72441
#
# Epoch 00037: val_accuracy did not improve from 0.72441
#
# Epoch 00038: val_accuracy did not improve from 0.72441
#
# Epoch 00039: val_accuracy did not improve from 0.72441
#
# Epoch 00040: val_accuracy did not improve from 0.72441
#
# Epoch 00041: val_accuracy did not improve from 0.72441
#
# Epoch 00042: val_accuracy did not improve from 0.72441
#
# Epoch 00043: val_accuracy did not improve from 0.72441
#
# Epoch 00044: val_accuracy did not improve from 0.72441
#
# Epoch 00045: val_accuracy did not improve from 0.72441
#
# Epoch 00046: val_accuracy did not improve from 0.72441
#
# Epoch 00047: val_accuracy did not improve from 0.72441
#
# Epoch 00048: val_accuracy did not improve from 0.72441
#
# Epoch 00049: val_accuracy did not improve from 0.72441
#
# Epoch 00050: val_accuracy did not improve from 0.72441
#
# Epoch 00051: val_accuracy did not improve from 0.72441
#
# Epoch 00052: val_accuracy did not improve from 0.72441
#
# Epoch 00053: val_accuracy did not improve from 0.72441
#
# Epoch 00054: val_accuracy did not improve from 0.72441
#
# Epoch 00055: val_accuracy did not improve from 0.72441
#
# Epoch 00056: val_accuracy did not improve from 0.72441
#
# Epoch 00057: val_accuracy did not improve from 0.72441
#
# Epoch 00058: val_accuracy did not improve from 0.72441
#
# Epoch 00059: val_accuracy did not improve from 0.72441
#
# Epoch 00060: val_accuracy did not improve from 0.72441
#
# Epoch 00061: val_accuracy did not improve from 0.72441
#
# Epoch 00062: val_accuracy did not improve from 0.72441
#
# Epoch 00063: val_accuracy did not improve from 0.72441
#
# Epoch 00064: val_accuracy did not improve from 0.72441
#
# Epoch 00065: val_accuracy did not improve from 0.72441
#
# Epoch 00066: val_accuracy did not improve from 0.72441
#
# Epoch 00067: val_accuracy did not improve from 0.72441
#
# Epoch 00068: val_accuracy did not improve from 0.72441
#
# Epoch 00069: val_accuracy improved from 0.72441 to 0.73228, saving model to weights-improvement-69-0.73.hdf5
#
# Epoch 00070: val_accuracy did not improve from 0.73228
#
# Epoch 00071: val_accuracy improved from 0.73228 to 0.73622, saving model to weights-improvement-71-0.74.hdf5
#
# Epoch 00072: val_accuracy did not improve from 0.73622
#
# Epoch 00073: val_accuracy did not improve from 0.73622
#
# Epoch 00074: val_accuracy did not improve from 0.73622
#
# Epoch 00075: val_accuracy did not improve from 0.73622
#
# Epoch 00076: val_accuracy did not improve from 0.73622
#
# Epoch 00077: val_accuracy did not improve from 0.73622
#
# Epoch 00078: val_accuracy did not improve from 0.73622
#
# Epoch 00079: val_accuracy did not improve from 0.73622
#
# Epoch 00080: val_accuracy did not improve from 0.73622
#
# Epoch 00081: val_accuracy improved from 0.73622 to 0.74016, saving model to weights-improvement-81-0.74.hdf5
#
# Epoch 00082: val_accuracy did not improve from 0.74016
#
# Epoch 00083: val_accuracy did not improve from 0.74016
#
# Epoch 00084: val_accuracy did not improve from 0.74016
#
# Epoch 00085: val_accuracy did not improve from 0.74016
#
# Epoch 00086: val_accuracy did not improve from 0.74016
#
# Epoch 00087: val_accuracy did not improve from 0.74016
#
# Epoch 00088: val_accuracy did not improve from 0.74016
#
# Epoch 00089: val_accuracy did not improve from 0.74016
#
# Epoch 00090: val_accuracy did not improve from 0.74016
#
# Epoch 00091: val_accuracy did not improve from 0.74016
#
# Epoch 00092: val_accuracy did not improve from 0.74016
#
# Epoch 00093: val_accuracy did not improve from 0.74016
#
# Epoch 00094: val_accuracy did not improve from 0.74016
#
# Epoch 00095: val_accuracy did not improve from 0.74016
#
# Epoch 00096: val_accuracy did not improve from 0.74016
#
# Epoch 00097: val_accuracy did not improve from 0.74016
#
# Epoch 00098: val_accuracy did not improve from 0.74016
#
# Epoch 00099: val_accuracy did not improve from 0.74016
#
# Epoch 00100: val_accuracy improved from 0.74016 to 0.74409, saving model to weights-improvement-100-0.74.hdf5
#
# Epoch 00101: val_accuracy did not improve from 0.74409
#
# Epoch 00102: val_accuracy did not improve from 0.74409
#
# Epoch 00103: val_accuracy did not improve from 0.74409
#
# Epoch 00104: val_accuracy did not improve from 0.74409
#
# Epoch 00105: val_accuracy did not improve from 0.74409
#
# Epoch 00106: val_accuracy did not improve from 0.74409
#
# Epoch 00107: val_accuracy did not improve from 0.74409
#
# Epoch 00108: val_accuracy did not improve from 0.74409
#
# Epoch 00109: val_accuracy did not improve from 0.74409
#
# Epoch 00110: val_accuracy did not improve from 0.74409
#
# Epoch 00111: val_accuracy did not improve from 0.74409
#
# Epoch 00112: val_accuracy did not improve from 0.74409
#
# Epoch 00113: val_accuracy improved from 0.74409 to 0.74803, saving model to weights-improvement-113-0.75.hdf5
#
# Epoch 00114: val_accuracy did not improve from 0.74803
#
# Epoch 00115: val_accuracy did not improve from 0.74803
#
# Epoch 00116: val_accuracy did not improve from 0.74803
#
# Epoch 00117: val_accuracy did not improve from 0.74803
#
# Epoch 00118: val_accuracy did not improve from 0.74803
#
# Epoch 00119: val_accuracy improved from 0.74803 to 0.75197, saving model to weights-improvement-119-0.75.hdf5
#
# Epoch 00120: val_accuracy did not improve from 0.75197
#
# Epoch 00121: val_accuracy improved from 0.75197 to 0.75591, saving model to weights-improvement-121-0.76.hdf5
#
# Epoch 00122: val_accuracy did not improve from 0.75591
#
# Epoch 00123: val_accuracy did not improve from 0.75591
#
# Epoch 00124: val_accuracy did not improve from 0.75591
#
# Epoch 00125: val_accuracy did not improve from 0.75591
#
# Epoch 00126: val_accuracy did not improve from 0.75591
#
# Epoch 00127: val_accuracy did not improve from 0.75591
#
# Epoch 00128: val_accuracy did not improve from 0.75591
#
# Epoch 00129: val_accuracy did not improve from 0.75591
#
# Epoch 00130: val_accuracy did not improve from 0.75591
#
# Epoch 00131: val_accuracy did not improve from 0.75591
#
# Epoch 00132: val_accuracy did not improve from 0.75591
#
# Epoch 00133: val_accuracy did not improve from 0.75591
#
# Epoch 00134: val_accuracy did not improve from 0.75591
#
# Epoch 00135: val_accuracy did not improve from 0.75591
#
# Epoch 00136: val_accuracy did not improve from 0.75591
#
# Epoch 00137: val_accuracy did not improve from 0.75591
#
# Epoch 00138: val_accuracy improved from 0.75591 to 0.76772, saving model to weights-improvement-138-0.77.hdf5
#
# Epoch 00139: val_accuracy did not improve from 0.76772
#
# Epoch 00140: val_accuracy did not improve from 0.76772
#
# Epoch 00141: val_accuracy did not improve from 0.76772
#
# Epoch 00142: val_accuracy did not improve from 0.76772
#
# Epoch 00143: val_accuracy did not improve from 0.76772
#
# Epoch 00144: val_accuracy did not improve from 0.76772
#
# Epoch 00145: val_accuracy did not improve from 0.76772
#
# Epoch 00146: val_accuracy did not improve from 0.76772
#
# Epoch 00147: val_accuracy did not improve from 0.76772
#
# Epoch 00148: val_accuracy did not improve from 0.76772
#
# Epoch 00149: val_accuracy did not improve from 0.76772
#
# Epoch 00150: val_accuracy did not improve from 0.76772

# %% [markdown]
# You will also see a number of files in your working directory containing the network weights in HDF5 format. For example:
#
# ```
# ...
# weights-improvement-51-0.69.hdf5
# weights-improvement-56-0.73.hdf5
# weights-improvement-63-0.74.hdf5
# weights-improvement-67-0.71.hdf5
# weights-improvement-94-0.74.hdf5
# ```

# %% [markdown]
# This is a straightforward checkpointing strategy. It may create many unnecessary checkpoint files if the validation accuracy moves up and down over training epochs. Nevertheless, it will ensure that you have a snapshot of the best model discovered during your run.

# %% [markdown]
# ## Checkpoint Best Neural Network Model Only

# %% [markdown]
# A simpler checkpoint strategy is to save the model weights to the same file, if and only if the validation accuracy improves. This can be done quickly using the same code from above and changing the output filename to be fixed (not include score or epoch information). In this case, model weights are written to the file `weights.best.hdf5` only if the classification accuracy of the model on the validation dataset improves over the best seen so far.

# %%
import tensorflow as tf

# MLP for Pima Indians Dataset Serialize to JSON and HDF5
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint

import numpy

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# load pima indians dataset
dataset = numpy.loadtxt(DATASET, delimiter=",")

# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# create model
model = Sequential()
model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
#model.load_weights('weights.best.hdf5')

# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# checkpoint
filepath="weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True,
mode='max')
callbacks_list = [checkpoint]

# %% [markdown]
# Running this example provides the following output (truncated for brevity):

# %%
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10, callbacks=callbacks_list,
verbose=0)
# Out:
# Epoch 00001: val_accuracy did not improve from 0.79134
#
# Epoch 00002: val_accuracy did not improve from 0.79134
#
# Epoch 00003: val_accuracy did not improve from 0.79134
#
# Epoch 00004: val_accuracy did not improve from 0.79134
#
# Epoch 00005: val_accuracy did not improve from 0.79134
#
# Epoch 00006: val_accuracy did not improve from 0.79134
#
# Epoch 00007: val_accuracy did not improve from 0.79134
#
# Epoch 00008: val_accuracy did not improve from 0.79134
#
# Epoch 00009: val_accuracy did not improve from 0.79134
#
# Epoch 00010: val_accuracy did not improve from 0.79134
#
# Epoch 00011: val_accuracy did not improve from 0.79134
#
# Epoch 00012: val_accuracy did not improve from 0.79134
#
# Epoch 00013: val_accuracy did not improve from 0.79134
#
# Epoch 00014: val_accuracy did not improve from 0.79134
#
# Epoch 00015: val_accuracy did not improve from 0.79134
#
# Epoch 00016: val_accuracy did not improve from 0.79134
#
# Epoch 00017: val_accuracy did not improve from 0.79134
#
# Epoch 00018: val_accuracy did not improve from 0.79134
#
# Epoch 00019: val_accuracy did not improve from 0.79134
#
# Epoch 00020: val_accuracy did not improve from 0.79134
#
# Epoch 00021: val_accuracy did not improve from 0.79134
#
# Epoch 00022: val_accuracy did not improve from 0.79134
#
# Epoch 00023: val_accuracy did not improve from 0.79134
#
# Epoch 00024: val_accuracy did not improve from 0.79134
#
# Epoch 00025: val_accuracy did not improve from 0.79134
#
# Epoch 00026: val_accuracy did not improve from 0.79134
#
# Epoch 00027: val_accuracy did not improve from 0.79134
#
# Epoch 00028: val_accuracy did not improve from 0.79134
#
# Epoch 00029: val_accuracy did not improve from 0.79134
#
# Epoch 00030: val_accuracy did not improve from 0.79134
#
# Epoch 00031: val_accuracy did not improve from 0.79134
#
# Epoch 00032: val_accuracy did not improve from 0.79134
#
# Epoch 00033: val_accuracy did not improve from 0.79134
#
# Epoch 00034: val_accuracy did not improve from 0.79134
#
# Epoch 00035: val_accuracy did not improve from 0.79134
#
# Epoch 00036: val_accuracy did not improve from 0.79134
#
# Epoch 00037: val_accuracy did not improve from 0.79134
#
# Epoch 00038: val_accuracy did not improve from 0.79134
#
# Epoch 00039: val_accuracy did not improve from 0.79134
#
# Epoch 00040: val_accuracy did not improve from 0.79134
#
# Epoch 00041: val_accuracy did not improve from 0.79134
#
# Epoch 00042: val_accuracy did not improve from 0.79134
#
# Epoch 00043: val_accuracy did not improve from 0.79134
#
# Epoch 00044: val_accuracy did not improve from 0.79134
#
# Epoch 00045: val_accuracy did not improve from 0.79134
#
# Epoch 00046: val_accuracy did not improve from 0.79134
#
# Epoch 00047: val_accuracy did not improve from 0.79134
#
# Epoch 00048: val_accuracy did not improve from 0.79134
#
# Epoch 00049: val_accuracy did not improve from 0.79134
#
# Epoch 00050: val_accuracy did not improve from 0.79134
#
# Epoch 00051: val_accuracy did not improve from 0.79134
#
# Epoch 00052: val_accuracy did not improve from 0.79134
#
# Epoch 00053: val_accuracy did not improve from 0.79134
#
# Epoch 00054: val_accuracy did not improve from 0.79134
#
# Epoch 00055: val_accuracy did not improve from 0.79134
#
# Epoch 00056: val_accuracy did not improve from 0.79134
#
# Epoch 00057: val_accuracy did not improve from 0.79134
#
# Epoch 00058: val_accuracy did not improve from 0.79134
#
# Epoch 00059: val_accuracy did not improve from 0.79134
#
# Epoch 00060: val_accuracy did not improve from 0.79134
#
# Epoch 00061: val_accuracy did not improve from 0.79134
#
# Epoch 00062: val_accuracy did not improve from 0.79134
#
# Epoch 00063: val_accuracy did not improve from 0.79134
#
# Epoch 00064: val_accuracy did not improve from 0.79134
#
# Epoch 00065: val_accuracy did not improve from 0.79134
#
# Epoch 00066: val_accuracy did not improve from 0.79134
#
# Epoch 00067: val_accuracy did not improve from 0.79134
#
# Epoch 00068: val_accuracy did not improve from 0.79134
#
# Epoch 00069: val_accuracy did not improve from 0.79134
#
# Epoch 00070: val_accuracy did not improve from 0.79134
#
# Epoch 00071: val_accuracy did not improve from 0.79134
#
# Epoch 00072: val_accuracy did not improve from 0.79134
#
# Epoch 00073: val_accuracy did not improve from 0.79134
#
# Epoch 00074: val_accuracy did not improve from 0.79134
#
# Epoch 00075: val_accuracy did not improve from 0.79134
#
# Epoch 00076: val_accuracy did not improve from 0.79134
#
# Epoch 00077: val_accuracy did not improve from 0.79134
#
# Epoch 00078: val_accuracy did not improve from 0.79134
#
# Epoch 00079: val_accuracy did not improve from 0.79134
#
# Epoch 00080: val_accuracy did not improve from 0.79134
#
# Epoch 00081: val_accuracy did not improve from 0.79134
#
# Epoch 00082: val_accuracy did not improve from 0.79134
#
# Epoch 00083: val_accuracy did not improve from 0.79134
#
# Epoch 00084: val_accuracy did not improve from 0.79134
#
# Epoch 00085: val_accuracy did not improve from 0.79134
#
# Epoch 00086: val_accuracy did not improve from 0.79134
#
# Epoch 00087: val_accuracy did not improve from 0.79134
#
# Epoch 00088: val_accuracy did not improve from 0.79134
#
# Epoch 00089: val_accuracy did not improve from 0.79134
#
# Epoch 00090: val_accuracy did not improve from 0.79134
#
# Epoch 00091: val_accuracy did not improve from 0.79134
#
# Epoch 00092: val_accuracy did not improve from 0.79134
#
# Epoch 00093: val_accuracy did not improve from 0.79134
#
# Epoch 00094: val_accuracy did not improve from 0.79134
#
# Epoch 00095: val_accuracy did not improve from 0.79134
#
# Epoch 00096: val_accuracy did not improve from 0.79134
#
# Epoch 00097: val_accuracy did not improve from 0.79134
#
# Epoch 00098: val_accuracy did not improve from 0.79134
#
# Epoch 00099: val_accuracy did not improve from 0.79134
#
# Epoch 00100: val_accuracy did not improve from 0.79134
#
# Epoch 00101: val_accuracy did not improve from 0.79134
#
# Epoch 00102: val_accuracy did not improve from 0.79134
#
# Epoch 00103: val_accuracy did not improve from 0.79134
#
# Epoch 00104: val_accuracy did not improve from 0.79134
#
# Epoch 00105: val_accuracy did not improve from 0.79134
#
# Epoch 00106: val_accuracy did not improve from 0.79134
#
# Epoch 00107: val_accuracy did not improve from 0.79134
#
# Epoch 00108: val_accuracy did not improve from 0.79134
#
# Epoch 00109: val_accuracy did not improve from 0.79134
#
# Epoch 00110: val_accuracy did not improve from 0.79134
#
# Epoch 00111: val_accuracy did not improve from 0.79134
#
# Epoch 00112: val_accuracy did not improve from 0.79134
#
# Epoch 00113: val_accuracy did not improve from 0.79134
#
# Epoch 00114: val_accuracy did not improve from 0.79134
#
# Epoch 00115: val_accuracy did not improve from 0.79134
#
# Epoch 00116: val_accuracy did not improve from 0.79134
#
# Epoch 00117: val_accuracy did not improve from 0.79134
#
# Epoch 00118: val_accuracy did not improve from 0.79134
#
# Epoch 00119: val_accuracy did not improve from 0.79134
#
# Epoch 00120: val_accuracy did not improve from 0.79134
#
# Epoch 00121: val_accuracy did not improve from 0.79134
#
# Epoch 00122: val_accuracy did not improve from 0.79134
#
# Epoch 00123: val_accuracy did not improve from 0.79134
#
# Epoch 00124: val_accuracy did not improve from 0.79134
#
# Epoch 00125: val_accuracy did not improve from 0.79134
#
# Epoch 00126: val_accuracy did not improve from 0.79134
#
# Epoch 00127: val_accuracy did not improve from 0.79134
#
# Epoch 00128: val_accuracy did not improve from 0.79134
#
# Epoch 00129: val_accuracy did not improve from 0.79134
#
# Epoch 00130: val_accuracy did not improve from 0.79134
#
# Epoch 00131: val_accuracy did not improve from 0.79134
#
# Epoch 00132: val_accuracy did not improve from 0.79134
#
# Epoch 00133: val_accuracy did not improve from 0.79134
#
# Epoch 00134: val_accuracy did not improve from 0.79134
#
# Epoch 00135: val_accuracy did not improve from 0.79134
#
# Epoch 00136: val_accuracy did not improve from 0.79134
#
# Epoch 00137: val_accuracy did not improve from 0.79134
#
# Epoch 00138: val_accuracy did not improve from 0.79134
#
# Epoch 00139: val_accuracy did not improve from 0.79134
#
# Epoch 00140: val_accuracy did not improve from 0.79134
#
# Epoch 00141: val_accuracy did not improve from 0.79134
#
# Epoch 00142: val_accuracy did not improve from 0.79134
#
# Epoch 00143: val_accuracy did not improve from 0.79134
#
# Epoch 00144: val_accuracy did not improve from 0.79134
#
# Epoch 00145: val_accuracy did not improve from 0.79134
#
# Epoch 00146: val_accuracy did not improve from 0.79134
#
# Epoch 00147: val_accuracy did not improve from 0.79134
#
# Epoch 00148: val_accuracy did not improve from 0.79134
#
# Epoch 00149: val_accuracy did not improve from 0.79134
#
# Epoch 00150: val_accuracy did not improve from 0.79134
#
# Epoch 00151: val_accuracy did not improve from 0.79134
#
# Epoch 00152: val_accuracy did not improve from 0.79134
#
# Epoch 00153: val_accuracy did not improve from 0.79134
#
# Epoch 00154: val_accuracy did not improve from 0.79134
#
# Epoch 00155: val_accuracy did not improve from 0.79134
#
# Epoch 00156: val_accuracy did not improve from 0.79134
#
# Epoch 00157: val_accuracy did not improve from 0.79134
#
# Epoch 00158: val_accuracy did not improve from 0.79134
#
# Epoch 00159: val_accuracy did not improve from 0.79134
#
# Epoch 00160: val_accuracy did not improve from 0.79134
#
# Epoch 00161: val_accuracy did not improve from 0.79134
#
# Epoch 00162: val_accuracy did not improve from 0.79134
#
# Epoch 00163: val_accuracy did not improve from 0.79134
#
# Epoch 00164: val_accuracy did not improve from 0.79134
#
# Epoch 00165: val_accuracy did not improve from 0.79134
#
# Epoch 00166: val_accuracy did not improve from 0.79134
#
# Epoch 00167: val_accuracy did not improve from 0.79134
#
# Epoch 00168: val_accuracy did not improve from 0.79134
#
# Epoch 00169: val_accuracy did not improve from 0.79134
#
# Epoch 00170: val_accuracy did not improve from 0.79134
#
# Epoch 00171: val_accuracy did not improve from 0.79134
#
# Epoch 00172: val_accuracy did not improve from 0.79134
#
# Epoch 00173: val_accuracy did not improve from 0.79134
#
# Epoch 00174: val_accuracy did not improve from 0.79134
#
# Epoch 00175: val_accuracy did not improve from 0.79134
#
# Epoch 00176: val_accuracy did not improve from 0.79134
#
# Epoch 00177: val_accuracy did not improve from 0.79134
#
# Epoch 00178: val_accuracy did not improve from 0.79134
#
# Epoch 00179: val_accuracy did not improve from 0.79134
#
# Epoch 00180: val_accuracy did not improve from 0.79134
#
# Epoch 00181: val_accuracy did not improve from 0.79134
#
# Epoch 00182: val_accuracy did not improve from 0.79134
#
# Epoch 00183: val_accuracy did not improve from 0.79134
#
# Epoch 00184: val_accuracy did not improve from 0.79134
#
# Epoch 00185: val_accuracy did not improve from 0.79134
#
# Epoch 00186: val_accuracy did not improve from 0.79134
#
# Epoch 00187: val_accuracy did not improve from 0.79134
#
# Epoch 00188: val_accuracy did not improve from 0.79134
#
# Epoch 00189: val_accuracy did not improve from 0.79134
#
# Epoch 00190: val_accuracy did not improve from 0.79134
#
# Epoch 00191: val_accuracy did not improve from 0.79134
#
# Epoch 00192: val_accuracy did not improve from 0.79134
#
# Epoch 00193: val_accuracy did not improve from 0.79134
#
# Epoch 00194: val_accuracy did not improve from 0.79134
#
# Epoch 00195: val_accuracy did not improve from 0.79134
#
# Epoch 00196: val_accuracy did not improve from 0.79134
#
# Epoch 00197: val_accuracy did not improve from 0.79134
#
# Epoch 00198: val_accuracy did not improve from 0.79134
#
# Epoch 00199: val_accuracy did not improve from 0.79134
#
# Epoch 00200: val_accuracy did not improve from 0.79134
#
# Epoch 00201: val_accuracy did not improve from 0.79134
#
# Epoch 00202: val_accuracy did not improve from 0.79134
#
# Epoch 00203: val_accuracy did not improve from 0.79134
#
# Epoch 00204: val_accuracy did not improve from 0.79134
#
# Epoch 00205: val_accuracy did not improve from 0.79134
#
# Epoch 00206: val_accuracy did not improve from 0.79134
#
# Epoch 00207: val_accuracy did not improve from 0.79134
#
# Epoch 00208: val_accuracy did not improve from 0.79134
#
# Epoch 00209: val_accuracy did not improve from 0.79134
#
# Epoch 00210: val_accuracy did not improve from 0.79134
#
# Epoch 00211: val_accuracy did not improve from 0.79134
#
# Epoch 00212: val_accuracy did not improve from 0.79134
#
# Epoch 00213: val_accuracy did not improve from 0.79134
#
# Epoch 00214: val_accuracy did not improve from 0.79134
#
# Epoch 00215: val_accuracy did not improve from 0.79134
#
# Epoch 00216: val_accuracy did not improve from 0.79134
#
# Epoch 00217: val_accuracy did not improve from 0.79134
#
# Epoch 00218: val_accuracy did not improve from 0.79134
#
# Epoch 00219: val_accuracy did not improve from 0.79134
#
# Epoch 00220: val_accuracy did not improve from 0.79134
#
# Epoch 00221: val_accuracy did not improve from 0.79134
#
# Epoch 00222: val_accuracy did not improve from 0.79134
#
# Epoch 00223: val_accuracy did not improve from 0.79134
#
# Epoch 00224: val_accuracy did not improve from 0.79134
#
# Epoch 00225: val_accuracy did not improve from 0.79134
#
# Epoch 00226: val_accuracy did not improve from 0.79134
#
# Epoch 00227: val_accuracy did not improve from 0.79134
#
# Epoch 00228: val_accuracy did not improve from 0.79134
#
# Epoch 00229: val_accuracy did not improve from 0.79134
#
# Epoch 00230: val_accuracy did not improve from 0.79134
#
# Epoch 00231: val_accuracy did not improve from 0.79134
#
# Epoch 00232: val_accuracy did not improve from 0.79134
#
# Epoch 00233: val_accuracy did not improve from 0.79134
#
# Epoch 00234: val_accuracy did not improve from 0.79134
#
# Epoch 00235: val_accuracy did not improve from 0.79134
#
# Epoch 00236: val_accuracy did not improve from 0.79134
#
# Epoch 00237: val_accuracy did not improve from 0.79134
#
# Epoch 00238: val_accuracy did not improve from 0.79134
#
# Epoch 00239: val_accuracy did not improve from 0.79134
#
# Epoch 00240: val_accuracy did not improve from 0.79134
#
# Epoch 00241: val_accuracy did not improve from 0.79134
#
# Epoch 00242: val_accuracy did not improve from 0.79134
#
# Epoch 00243: val_accuracy did not improve from 0.79134
#
# Epoch 00244: val_accuracy did not improve from 0.79134
#
# Epoch 00245: val_accuracy did not improve from 0.79134
#
# Epoch 00246: val_accuracy did not improve from 0.79134
#
# Epoch 00247: val_accuracy did not improve from 0.79134
#
# Epoch 00248: val_accuracy did not improve from 0.79134
#
# Epoch 00249: val_accuracy did not improve from 0.79134
#
# Epoch 00250: val_accuracy did not improve from 0.79134
#
# Epoch 00251: val_accuracy did not improve from 0.79134
#
# Epoch 00252: val_accuracy did not improve from 0.79134
#
# Epoch 00253: val_accuracy did not improve from 0.79134
#
# Epoch 00254: val_accuracy did not improve from 0.79134
#
# Epoch 00255: val_accuracy did not improve from 0.79134
#
# Epoch 00256: val_accuracy did not improve from 0.79134
#
# Epoch 00257: val_accuracy did not improve from 0.79134
#
# Epoch 00258: val_accuracy did not improve from 0.79134
#
# Epoch 00259: val_accuracy did not improve from 0.79134
#
# Epoch 00260: val_accuracy did not improve from 0.79134
#
# Epoch 00261: val_accuracy did not improve from 0.79134
#
# Epoch 00262: val_accuracy did not improve from 0.79134
#
# Epoch 00263: val_accuracy did not improve from 0.79134
#
# Epoch 00264: val_accuracy did not improve from 0.79134
#
# Epoch 00265: val_accuracy did not improve from 0.79134
#
# Epoch 00266: val_accuracy did not improve from 0.79134
#
# Epoch 00267: val_accuracy did not improve from 0.79134
#
# Epoch 00268: val_accuracy did not improve from 0.79134
#
# Epoch 00269: val_accuracy did not improve from 0.79134
#
# Epoch 00270: val_accuracy did not improve from 0.79134
#
# Epoch 00271: val_accuracy did not improve from 0.79134
#
# Epoch 00272: val_accuracy did not improve from 0.79134
#
# Epoch 00273: val_accuracy did not improve from 0.79134
#
# Epoch 00274: val_accuracy did not improve from 0.79134
#
# Epoch 00275: val_accuracy did not improve from 0.79134
#
# Epoch 00276: val_accuracy did not improve from 0.79134
#
# Epoch 00277: val_accuracy did not improve from 0.79134
#
# Epoch 00278: val_accuracy did not improve from 0.79134
#
# Epoch 00279: val_accuracy did not improve from 0.79134
#
# Epoch 00280: val_accuracy did not improve from 0.79134
#
# Epoch 00281: val_accuracy did not improve from 0.79134
#
# Epoch 00282: val_accuracy did not improve from 0.79134
#
# Epoch 00283: val_accuracy did not improve from 0.79134
#
# Epoch 00284: val_accuracy did not improve from 0.79134
#
# Epoch 00285: val_accuracy did not improve from 0.79134
#
# Epoch 00286: val_accuracy did not improve from 0.79134
#
# Epoch 00287: val_accuracy did not improve from 0.79134
#
# Epoch 00288: val_accuracy did not improve from 0.79134
#
# Epoch 00289: val_accuracy did not improve from 0.79134
#
# Epoch 00290: val_accuracy did not improve from 0.79134
#
# Epoch 00291: val_accuracy did not improve from 0.79134
#
# Epoch 00292: val_accuracy did not improve from 0.79134
#
# Epoch 00293: val_accuracy did not improve from 0.79134
#
# Epoch 00294: val_accuracy did not improve from 0.79134
#
# Epoch 00295: val_accuracy did not improve from 0.79134
#
# Epoch 00296: val_accuracy did not improve from 0.79134
#
# Epoch 00297: val_accuracy did not improve from 0.79134
#
# Epoch 00298: val_accuracy did not improve from 0.79134
#
# Epoch 00299: val_accuracy did not improve from 0.79134
#
# Epoch 00300: val_accuracy did not improve from 0.79134
#
# Epoch 00301: val_accuracy did not improve from 0.79134
#
# Epoch 00302: val_accuracy did not improve from 0.79134
#
# Epoch 00303: val_accuracy did not improve from 0.79134
#
# Epoch 00304: val_accuracy did not improve from 0.79134
#
# Epoch 00305: val_accuracy did not improve from 0.79134
#
# Epoch 00306: val_accuracy did not improve from 0.79134
#
# Epoch 00307: val_accuracy did not improve from 0.79134
#
# Epoch 00308: val_accuracy did not improve from 0.79134
#
# Epoch 00309: val_accuracy did not improve from 0.79134
#
# Epoch 00310: val_accuracy did not improve from 0.79134
#
# Epoch 00311: val_accuracy did not improve from 0.79134
#
# Epoch 00312: val_accuracy did not improve from 0.79134
#
# Epoch 00313: val_accuracy did not improve from 0.79134
#
# Epoch 00314: val_accuracy did not improve from 0.79134
#
# Epoch 00315: val_accuracy did not improve from 0.79134
#
# Epoch 00316: val_accuracy did not improve from 0.79134
#
# Epoch 00317: val_accuracy did not improve from 0.79134
#
# Epoch 00318: val_accuracy did not improve from 0.79134
#
# Epoch 00319: val_accuracy did not improve from 0.79134
#
# Epoch 00320: val_accuracy did not improve from 0.79134
#
# Epoch 00321: val_accuracy did not improve from 0.79134
#
# Epoch 00322: val_accuracy did not improve from 0.79134
#
# Epoch 00323: val_accuracy did not improve from 0.79134
#
# Epoch 00324: val_accuracy did not improve from 0.79134
#
# Epoch 00325: val_accuracy did not improve from 0.79134
#
# Epoch 00326: val_accuracy did not improve from 0.79134
#
# Epoch 00327: val_accuracy did not improve from 0.79134
#
# Epoch 00328: val_accuracy did not improve from 0.79134
#
# Epoch 00329: val_accuracy did not improve from 0.79134
#
# Epoch 00330: val_accuracy did not improve from 0.79134
#
# Epoch 00331: val_accuracy did not improve from 0.79134
#
# Epoch 00332: val_accuracy did not improve from 0.79134
#
# Epoch 00333: val_accuracy did not improve from 0.79134
#
# Epoch 00334: val_accuracy did not improve from 0.79134
#
# Epoch 00335: val_accuracy did not improve from 0.79134
#
# Epoch 00336: val_accuracy did not improve from 0.79134
#
# Epoch 00337: val_accuracy did not improve from 0.79134
#
# Epoch 00338: val_accuracy did not improve from 0.79134
#
# Epoch 00339: val_accuracy did not improve from 0.79134
#
# Epoch 00340: val_accuracy did not improve from 0.79134
#
# Epoch 00341: val_accuracy did not improve from 0.79134
#
# Epoch 00342: val_accuracy did not improve from 0.79134
#
# Epoch 00343: val_accuracy did not improve from 0.79134
#
# Epoch 00344: val_accuracy did not improve from 0.79134
#
# Epoch 00345: val_accuracy did not improve from 0.79134
#
# Epoch 00346: val_accuracy did not improve from 0.79134
#
# Epoch 00347: val_accuracy did not improve from 0.79134
#
# Epoch 00348: val_accuracy did not improve from 0.79134
#
# Epoch 00349: val_accuracy did not improve from 0.79134
#
# Epoch 00350: val_accuracy did not improve from 0.79134
#
# Epoch 00351: val_accuracy did not improve from 0.79134
#
# Epoch 00352: val_accuracy did not improve from 0.79134
#
# Epoch 00353: val_accuracy did not improve from 0.79134
#
# Epoch 00354: val_accuracy did not improve from 0.79134
#
# Epoch 00355: val_accuracy did not improve from 0.79134
#
# Epoch 00356: val_accuracy did not improve from 0.79134
#
# Epoch 00357: val_accuracy did not improve from 0.79134
#
# Epoch 00358: val_accuracy did not improve from 0.79134
#
# Epoch 00359: val_accuracy did not improve from 0.79134
#
# Epoch 00360: val_accuracy did not improve from 0.79134
#
# Epoch 00361: val_accuracy did not improve from 0.79134
#
# Epoch 00362: val_accuracy did not improve from 0.79134
#
# Epoch 00363: val_accuracy did not improve from 0.79134
#
# Epoch 00364: val_accuracy did not improve from 0.79134
#
# Epoch 00365: val_accuracy did not improve from 0.79134
#
# Epoch 00366: val_accuracy did not improve from 0.79134
#
# Epoch 00367: val_accuracy did not improve from 0.79134
#
# Epoch 00368: val_accuracy did not improve from 0.79134
#
# Epoch 00369: val_accuracy did not improve from 0.79134
#
# Epoch 00370: val_accuracy did not improve from 0.79134
#
# Epoch 00371: val_accuracy did not improve from 0.79134
#
# Epoch 00372: val_accuracy did not improve from 0.79134
#
# Epoch 00373: val_accuracy did not improve from 0.79134
#
# Epoch 00374: val_accuracy did not improve from 0.79134
#
# Epoch 00375: val_accuracy did not improve from 0.79134
#
# Epoch 00376: val_accuracy did not improve from 0.79134
#
# Epoch 00377: val_accuracy did not improve from 0.79134
#
# Epoch 00378: val_accuracy did not improve from 0.79134
#
# Epoch 00379: val_accuracy did not improve from 0.79134
#
# Epoch 00380: val_accuracy did not improve from 0.79134
#
# Epoch 00381: val_accuracy did not improve from 0.79134
#
# Epoch 00382: val_accuracy did not improve from 0.79134
#
# Epoch 00383: val_accuracy did not improve from 0.79134
#
# Epoch 00384: val_accuracy did not improve from 0.79134
#
# Epoch 00385: val_accuracy did not improve from 0.79134
#
# Epoch 00386: val_accuracy did not improve from 0.79134
#
# Epoch 00387: val_accuracy did not improve from 0.79134
#
# Epoch 00388: val_accuracy did not improve from 0.79134
#
# Epoch 00389: val_accuracy did not improve from 0.79134
#
# Epoch 00390: val_accuracy did not improve from 0.79134
#
# Epoch 00391: val_accuracy did not improve from 0.79134
#
# Epoch 00392: val_accuracy did not improve from 0.79134
#
# Epoch 00393: val_accuracy did not improve from 0.79134
#
# Epoch 00394: val_accuracy did not improve from 0.79134
#
# Epoch 00395: val_accuracy did not improve from 0.79134
#
# Epoch 00396: val_accuracy did not improve from 0.79134
#
# Epoch 00397: val_accuracy did not improve from 0.79134
#
# Epoch 00398: val_accuracy did not improve from 0.79134
#
# Epoch 00399: val_accuracy did not improve from 0.79134
#
# Epoch 00400: val_accuracy did not improve from 0.79134
#
# Epoch 00401: val_accuracy did not improve from 0.79134
#
# Epoch 00402: val_accuracy did not improve from 0.79134
#
# Epoch 00403: val_accuracy did not improve from 0.79134
#
# Epoch 00404: val_accuracy did not improve from 0.79134
#
# Epoch 00405: val_accuracy did not improve from 0.79134
#
# Epoch 00406: val_accuracy did not improve from 0.79134
#
# Epoch 00407: val_accuracy did not improve from 0.79134
#
# Epoch 00408: val_accuracy did not improve from 0.79134
#
# Epoch 00409: val_accuracy did not improve from 0.79134
#
# Epoch 00410: val_accuracy did not improve from 0.79134
#
# Epoch 00411: val_accuracy did not improve from 0.79134
#
# Epoch 00412: val_accuracy did not improve from 0.79134
#
# Epoch 00413: val_accuracy did not improve from 0.79134
#
# Epoch 00414: val_accuracy did not improve from 0.79134
#
# Epoch 00415: val_accuracy did not improve from 0.79134
#
# Epoch 00416: val_accuracy did not improve from 0.79134
#
# Epoch 00417: val_accuracy did not improve from 0.79134
#
# Epoch 00418: val_accuracy did not improve from 0.79134
#
# Epoch 00419: val_accuracy did not improve from 0.79134
#
# Epoch 00420: val_accuracy did not improve from 0.79134
#
# Epoch 00421: val_accuracy did not improve from 0.79134
#
# Epoch 00422: val_accuracy did not improve from 0.79134
#
# Epoch 00423: val_accuracy did not improve from 0.79134
#
# Epoch 00424: val_accuracy did not improve from 0.79134
#
# Epoch 00425: val_accuracy did not improve from 0.79134
#
# Epoch 00426: val_accuracy did not improve from 0.79134
#
# Epoch 00427: val_accuracy did not improve from 0.79134
#
# Epoch 00428: val_accuracy did not improve from 0.79134
#
# Epoch 00429: val_accuracy did not improve from 0.79134
#
# Epoch 00430: val_accuracy did not improve from 0.79134
#
# Epoch 00431: val_accuracy did not improve from 0.79134
#
# Epoch 00432: val_accuracy did not improve from 0.79134
#
# Epoch 00433: val_accuracy did not improve from 0.79134
#
# Epoch 00434: val_accuracy did not improve from 0.79134
#
# Epoch 00435: val_accuracy did not improve from 0.79134
#
# Epoch 00436: val_accuracy did not improve from 0.79134
#
# Epoch 00437: val_accuracy did not improve from 0.79134
#
# Epoch 00438: val_accuracy did not improve from 0.79134
#
# Epoch 00439: val_accuracy did not improve from 0.79134
#
# Epoch 00440: val_accuracy did not improve from 0.79134
#
# Epoch 00441: val_accuracy did not improve from 0.79134
#
# Epoch 00442: val_accuracy did not improve from 0.79134
#
# Epoch 00443: val_accuracy did not improve from 0.79134
#
# Epoch 00444: val_accuracy did not improve from 0.79134
#
# Epoch 00445: val_accuracy did not improve from 0.79134
#
# Epoch 00446: val_accuracy did not improve from 0.79134
#
# Epoch 00447: val_accuracy did not improve from 0.79134
#
# Epoch 00448: val_accuracy did not improve from 0.79134
#
# Epoch 00449: val_accuracy did not improve from 0.79134
#
# Epoch 00450: val_accuracy did not improve from 0.79134
#
# Epoch 00451: val_accuracy did not improve from 0.79134
#
# Epoch 00452: val_accuracy did not improve from 0.79134
#
# Epoch 00453: val_accuracy did not improve from 0.79134
#
# Epoch 00454: val_accuracy did not improve from 0.79134
#
# Epoch 00455: val_accuracy did not improve from 0.79134
#
# Epoch 00456: val_accuracy did not improve from 0.79134
#
# Epoch 00457: val_accuracy did not improve from 0.79134
#
# Epoch 00458: val_accuracy did not improve from 0.79134
#
# Epoch 00459: val_accuracy did not improve from 0.79134
#
# Epoch 00460: val_accuracy did not improve from 0.79134
#
# Epoch 00461: val_accuracy did not improve from 0.79134
#
# Epoch 00462: val_accuracy did not improve from 0.79134
#
# Epoch 00463: val_accuracy did not improve from 0.79134
#
# Epoch 00464: val_accuracy did not improve from 0.79134
#
# Epoch 00465: val_accuracy did not improve from 0.79134
#
# Epoch 00466: val_accuracy did not improve from 0.79134
#
# Epoch 00467: val_accuracy did not improve from 0.79134
#
# Epoch 00468: val_accuracy did not improve from 0.79134
#
# Epoch 00469: val_accuracy did not improve from 0.79134
#
# Epoch 00470: val_accuracy did not improve from 0.79134
#
# Epoch 00471: val_accuracy did not improve from 0.79134
#
# Epoch 00472: val_accuracy did not improve from 0.79134
#
# Epoch 00473: val_accuracy did not improve from 0.79134
#
# Epoch 00474: val_accuracy did not improve from 0.79134
#
# Epoch 00475: val_accuracy did not improve from 0.79134
#
# Epoch 00476: val_accuracy did not improve from 0.79134
#
# Epoch 00477: val_accuracy did not improve from 0.79134
#
# Epoch 00478: val_accuracy did not improve from 0.79134
#
# Epoch 00479: val_accuracy did not improve from 0.79134
#
# Epoch 00480: val_accuracy did not improve from 0.79134
#
# Epoch 00481: val_accuracy did not improve from 0.79134
#
# Epoch 00482: val_accuracy did not improve from 0.79134
#
# Epoch 00483: val_accuracy did not improve from 0.79134
#
# Epoch 00484: val_accuracy did not improve from 0.79134
#
# Epoch 00485: val_accuracy did not improve from 0.79134
#
# Epoch 00486: val_accuracy did not improve from 0.79134
#
# Epoch 00487: val_accuracy did not improve from 0.79134
#
# Epoch 00488: val_accuracy did not improve from 0.79134
#
# Epoch 00489: val_accuracy did not improve from 0.79134
#
# Epoch 00490: val_accuracy did not improve from 0.79134
#
# Epoch 00491: val_accuracy did not improve from 0.79134
#
# Epoch 00492: val_accuracy did not improve from 0.79134
#
# Epoch 00493: val_accuracy did not improve from 0.79134
#
# Epoch 00494: val_accuracy did not improve from 0.79134
#
# Epoch 00495: val_accuracy did not improve from 0.79134
#
# Epoch 00496: val_accuracy did not improve from 0.79134
#
# Epoch 00497: val_accuracy did not improve from 0.79134
#
# Epoch 00498: val_accuracy did not improve from 0.79134
#
# Epoch 00499: val_accuracy did not improve from 0.79134
#
# Epoch 00500: val_accuracy did not improve from 0.79134
#
# Epoch 00501: val_accuracy did not improve from 0.79134
#
# Epoch 00502: val_accuracy did not improve from 0.79134
#
# Epoch 00503: val_accuracy did not improve from 0.79134
#
# Epoch 00504: val_accuracy did not improve from 0.79134
#
# Epoch 00505: val_accuracy did not improve from 0.79134
#
# Epoch 00506: val_accuracy did not improve from 0.79134
#
# Epoch 00507: val_accuracy did not improve from 0.79134
#
# Epoch 00508: val_accuracy did not improve from 0.79134
#
# Epoch 00509: val_accuracy did not improve from 0.79134
#
# Epoch 00510: val_accuracy did not improve from 0.79134
#
# Epoch 00511: val_accuracy did not improve from 0.79134
#
# Epoch 00512: val_accuracy did not improve from 0.79134
#
# Epoch 00513: val_accuracy did not improve from 0.79134
#
# Epoch 00514: val_accuracy did not improve from 0.79134
#
# Epoch 00515: val_accuracy did not improve from 0.79134
#
# Epoch 00516: val_accuracy did not improve from 0.79134
#
# Epoch 00517: val_accuracy did not improve from 0.79134
#
# Epoch 00518: val_accuracy did not improve from 0.79134
#
# Epoch 00519: val_accuracy did not improve from 0.79134
#
# Epoch 00520: val_accuracy did not improve from 0.79134
#
# Epoch 00521: val_accuracy did not improve from 0.79134
#
# Epoch 00522: val_accuracy did not improve from 0.79134
#
# Epoch 00523: val_accuracy did not improve from 0.79134
#
# Epoch 00524: val_accuracy did not improve from 0.79134
#
# Epoch 00525: val_accuracy did not improve from 0.79134
#
# Epoch 00526: val_accuracy did not improve from 0.79134
#
# Epoch 00527: val_accuracy did not improve from 0.79134
#
# Epoch 00528: val_accuracy did not improve from 0.79134
#
# Epoch 00529: val_accuracy did not improve from 0.79134
#
# Epoch 00530: val_accuracy did not improve from 0.79134
#
# Epoch 00531: val_accuracy did not improve from 0.79134
#
# Epoch 00532: val_accuracy did not improve from 0.79134
#
# Epoch 00533: val_accuracy did not improve from 0.79134
#
# Epoch 00534: val_accuracy did not improve from 0.79134
#
# Epoch 00535: val_accuracy did not improve from 0.79134
#
# Epoch 00536: val_accuracy did not improve from 0.79134
#
# Epoch 00537: val_accuracy did not improve from 0.79134
#
# Epoch 00538: val_accuracy did not improve from 0.79134
#
# Epoch 00539: val_accuracy did not improve from 0.79134
#
# Epoch 00540: val_accuracy did not improve from 0.79134
#
# Epoch 00541: val_accuracy did not improve from 0.79134
#
# Epoch 00542: val_accuracy did not improve from 0.79134
#
# Epoch 00543: val_accuracy did not improve from 0.79134
#
# Epoch 00544: val_accuracy did not improve from 0.79134
#
# Epoch 00545: val_accuracy did not improve from 0.79134
#
# Epoch 00546: val_accuracy did not improve from 0.79134
#
# Epoch 00547: val_accuracy did not improve from 0.79134
#
# Epoch 00548: val_accuracy did not improve from 0.79134
#
# Epoch 00549: val_accuracy did not improve from 0.79134
#
# Epoch 00550: val_accuracy did not improve from 0.79134
#
# Epoch 00551: val_accuracy did not improve from 0.79134
#
# Epoch 00552: val_accuracy did not improve from 0.79134
#
# Epoch 00553: val_accuracy did not improve from 0.79134
#
# Epoch 00554: val_accuracy did not improve from 0.79134
#
# Epoch 00555: val_accuracy did not improve from 0.79134
#
# Epoch 00556: val_accuracy did not improve from 0.79134
#
# Epoch 00557: val_accuracy did not improve from 0.79134
#
# Epoch 00558: val_accuracy did not improve from 0.79134
#
# Epoch 00559: val_accuracy did not improve from 0.79134
#
# Epoch 00560: val_accuracy did not improve from 0.79134
#
# Epoch 00561: val_accuracy did not improve from 0.79134
#
# Epoch 00562: val_accuracy did not improve from 0.79134
#
# Epoch 00563: val_accuracy did not improve from 0.79134
#
# Epoch 00564: val_accuracy did not improve from 0.79134
#
# Epoch 00565: val_accuracy did not improve from 0.79134
#
# Epoch 00566: val_accuracy did not improve from 0.79134
#
# Epoch 00567: val_accuracy did not improve from 0.79134
#
# Epoch 00568: val_accuracy did not improve from 0.79134
#
# Epoch 00569: val_accuracy did not improve from 0.79134
#
# Epoch 00570: val_accuracy did not improve from 0.79134
#
# Epoch 00571: val_accuracy did not improve from 0.79134
#
# Epoch 00572: val_accuracy did not improve from 0.79134
#
# Epoch 00573: val_accuracy did not improve from 0.79134
#
# Epoch 00574: val_accuracy did not improve from 0.79134
#
# Epoch 00575: val_accuracy did not improve from 0.79134
#
# Epoch 00576: val_accuracy did not improve from 0.79134
#
# Epoch 00577: val_accuracy did not improve from 0.79134
#
# Epoch 00578: val_accuracy did not improve from 0.79134
#
# Epoch 00579: val_accuracy did not improve from 0.79134
#
# Epoch 00580: val_accuracy did not improve from 0.79134
#
# Epoch 00581: val_accuracy did not improve from 0.79134
#
# Epoch 00582: val_accuracy did not improve from 0.79134
#
# Epoch 00583: val_accuracy did not improve from 0.79134
#
# Epoch 00584: val_accuracy did not improve from 0.79134
#
# Epoch 00585: val_accuracy did not improve from 0.79134
#
# Epoch 00586: val_accuracy did not improve from 0.79134
#
# Epoch 00587: val_accuracy did not improve from 0.79134
#
# Epoch 00588: val_accuracy did not improve from 0.79134
#
# Epoch 00589: val_accuracy did not improve from 0.79134
#
# Epoch 00590: val_accuracy did not improve from 0.79134
#
# Epoch 00591: val_accuracy did not improve from 0.79134
#
# Epoch 00592: val_accuracy did not improve from 0.79134
#
# Epoch 00593: val_accuracy did not improve from 0.79134
#
# Epoch 00594: val_accuracy did not improve from 0.79134
#
# Epoch 00595: val_accuracy did not improve from 0.79134
#
# Epoch 00596: val_accuracy did not improve from 0.79134
#
# Epoch 00597: val_accuracy did not improve from 0.79134
#
# Epoch 00598: val_accuracy did not improve from 0.79134
#
# Epoch 00599: val_accuracy did not improve from 0.79134
#
# Epoch 00600: val_accuracy did not improve from 0.79134
#
# Epoch 00601: val_accuracy did not improve from 0.79134
#
# Epoch 00602: val_accuracy did not improve from 0.79134
#
# Epoch 00603: val_accuracy did not improve from 0.79134
#
# Epoch 00604: val_accuracy did not improve from 0.79134
#
# Epoch 00605: val_accuracy did not improve from 0.79134
#
# Epoch 00606: val_accuracy did not improve from 0.79134
#
# Epoch 00607: val_accuracy did not improve from 0.79134
#
# Epoch 00608: val_accuracy did not improve from 0.79134
#
# Epoch 00609: val_accuracy did not improve from 0.79134
#
# Epoch 00610: val_accuracy did not improve from 0.79134
#
# Epoch 00611: val_accuracy did not improve from 0.79134
#
# Epoch 00612: val_accuracy did not improve from 0.79134
#
# Epoch 00613: val_accuracy did not improve from 0.79134
#
# Epoch 00614: val_accuracy did not improve from 0.79134
#
# Epoch 00615: val_accuracy did not improve from 0.79134
#
# Epoch 00616: val_accuracy did not improve from 0.79134
#
# Epoch 00617: val_accuracy did not improve from 0.79134
#
# Epoch 00618: val_accuracy did not improve from 0.79134
#
# Epoch 00619: val_accuracy did not improve from 0.79134
#
# Epoch 00620: val_accuracy did not improve from 0.79134
#
# Epoch 00621: val_accuracy did not improve from 0.79134
#
# Epoch 00622: val_accuracy did not improve from 0.79134
#
# Epoch 00623: val_accuracy did not improve from 0.79134
#
# Epoch 00624: val_accuracy did not improve from 0.79134
#
# Epoch 00625: val_accuracy did not improve from 0.79134
#
# Epoch 00626: val_accuracy did not improve from 0.79134
#
# Epoch 00627: val_accuracy did not improve from 0.79134
#
# Epoch 00628: val_accuracy did not improve from 0.79134
#
# Epoch 00629: val_accuracy did not improve from 0.79134
#
# Epoch 00630: val_accuracy did not improve from 0.79134
#
# Epoch 00631: val_accuracy did not improve from 0.79134
#
# Epoch 00632: val_accuracy did not improve from 0.79134
#
# Epoch 00633: val_accuracy did not improve from 0.79134
#
# Epoch 00634: val_accuracy did not improve from 0.79134
#
# Epoch 00635: val_accuracy did not improve from 0.79134
#
# Epoch 00636: val_accuracy did not improve from 0.79134
#
# Epoch 00637: val_accuracy did not improve from 0.79134
#
# Epoch 00638: val_accuracy did not improve from 0.79134
#
# Epoch 00639: val_accuracy did not improve from 0.79134
#
# Epoch 00640: val_accuracy did not improve from 0.79134
#
# Epoch 00641: val_accuracy did not improve from 0.79134
#
# Epoch 00642: val_accuracy did not improve from 0.79134
#
# Epoch 00643: val_accuracy did not improve from 0.79134
#
# Epoch 00644: val_accuracy did not improve from 0.79134
#
# Epoch 00645: val_accuracy did not improve from 0.79134
#
# Epoch 00646: val_accuracy did not improve from 0.79134
#
# Epoch 00647: val_accuracy did not improve from 0.79134
#
# Epoch 00648: val_accuracy did not improve from 0.79134
#
# Epoch 00649: val_accuracy did not improve from 0.79134
#
# Epoch 00650: val_accuracy did not improve from 0.79134
#
# Epoch 00651: val_accuracy did not improve from 0.79134
#
# Epoch 00652: val_accuracy did not improve from 0.79134
#
# Epoch 00653: val_accuracy did not improve from 0.79134
#
# Epoch 00654: val_accuracy did not improve from 0.79134
#
# Epoch 00655: val_accuracy did not improve from 0.79134
#
# Epoch 00656: val_accuracy did not improve from 0.79134
#
# Epoch 00657: val_accuracy did not improve from 0.79134
#
# Epoch 00658: val_accuracy did not improve from 0.79134
#
# Epoch 00659: val_accuracy did not improve from 0.79134
#
# Epoch 00660: val_accuracy did not improve from 0.79134
#
# Epoch 00661: val_accuracy did not improve from 0.79134
#
# Epoch 00662: val_accuracy did not improve from 0.79134
#
# Epoch 00663: val_accuracy did not improve from 0.79134
#
# Epoch 00664: val_accuracy did not improve from 0.79134
#
# Epoch 00665: val_accuracy did not improve from 0.79134
#
# Epoch 00666: val_accuracy did not improve from 0.79134
#
# Epoch 00667: val_accuracy did not improve from 0.79134
#
# Epoch 00668: val_accuracy did not improve from 0.79134
#
# Epoch 00669: val_accuracy did not improve from 0.79134
#
# Epoch 00670: val_accuracy did not improve from 0.79134
#
# Epoch 00671: val_accuracy did not improve from 0.79134
#
# Epoch 00672: val_accuracy did not improve from 0.79134
#
# Epoch 00673: val_accuracy did not improve from 0.79134
#
# Epoch 00674: val_accuracy did not improve from 0.79134
#
# Epoch 00675: val_accuracy did not improve from 0.79134
#
# Epoch 00676: val_accuracy did not improve from 0.79134
#
# Epoch 00677: val_accuracy did not improve from 0.79134
#
# Epoch 00678: val_accuracy did not improve from 0.79134
#
# Epoch 00679: val_accuracy did not improve from 0.79134
#
# Epoch 00680: val_accuracy did not improve from 0.79134
#
# Epoch 00681: val_accuracy did not improve from 0.79134
#
# Epoch 00682: val_accuracy did not improve from 0.79134
#
# Epoch 00683: val_accuracy did not improve from 0.79134
#
# Epoch 00684: val_accuracy did not improve from 0.79134
#
# Epoch 00685: val_accuracy did not improve from 0.79134
#
# Epoch 00686: val_accuracy did not improve from 0.79134
#
# Epoch 00687: val_accuracy did not improve from 0.79134
#
# Epoch 00688: val_accuracy did not improve from 0.79134
#
# Epoch 00689: val_accuracy did not improve from 0.79134
#
# Epoch 00690: val_accuracy did not improve from 0.79134
#
# Epoch 00691: val_accuracy did not improve from 0.79134
#
# Epoch 00692: val_accuracy did not improve from 0.79134
#
# Epoch 00693: val_accuracy did not improve from 0.79134
#
# Epoch 00694: val_accuracy did not improve from 0.79134
#
# Epoch 00695: val_accuracy did not improve from 0.79134
#
# Epoch 00696: val_accuracy did not improve from 0.79134
#
# Epoch 00697: val_accuracy did not improve from 0.79134
#
# Epoch 00698: val_accuracy did not improve from 0.79134
#
# Epoch 00699: val_accuracy did not improve from 0.79134
#
# Epoch 00700: val_accuracy did not improve from 0.79134
#
# Epoch 00701: val_accuracy did not improve from 0.79134
#
# Epoch 00702: val_accuracy did not improve from 0.79134
#
# Epoch 00703: val_accuracy did not improve from 0.79134
#
# Epoch 00704: val_accuracy did not improve from 0.79134
#
# Epoch 00705: val_accuracy did not improve from 0.79134
#
# Epoch 00706: val_accuracy did not improve from 0.79134
#
# Epoch 00707: val_accuracy did not improve from 0.79134
#
# Epoch 00708: val_accuracy did not improve from 0.79134
#
# Epoch 00709: val_accuracy did not improve from 0.79134
#
# Epoch 00710: val_accuracy did not improve from 0.79134
#
# Epoch 00711: val_accuracy did not improve from 0.79134
#
# Epoch 00712: val_accuracy did not improve from 0.79134
#
# Epoch 00713: val_accuracy did not improve from 0.79134
#
# Epoch 00714: val_accuracy did not improve from 0.79134
#
# Epoch 00715: val_accuracy did not improve from 0.79134
#
# Epoch 00716: val_accuracy did not improve from 0.79134
#
# Epoch 00717: val_accuracy did not improve from 0.79134
#
# Epoch 00718: val_accuracy did not improve from 0.79134
#
# Epoch 00719: val_accuracy did not improve from 0.79134
#
# Epoch 00720: val_accuracy did not improve from 0.79134
#
# Epoch 00721: val_accuracy did not improve from 0.79134
#
# Epoch 00722: val_accuracy did not improve from 0.79134
#
# Epoch 00723: val_accuracy did not improve from 0.79134
#
# Epoch 00724: val_accuracy did not improve from 0.79134
#
# Epoch 00725: val_accuracy did not improve from 0.79134
#
# Epoch 00726: val_accuracy did not improve from 0.79134
#
# Epoch 00727: val_accuracy did not improve from 0.79134
#
# Epoch 00728: val_accuracy did not improve from 0.79134
#
# Epoch 00729: val_accuracy did not improve from 0.79134
#
# Epoch 00730: val_accuracy did not improve from 0.79134
#
# Epoch 00731: val_accuracy did not improve from 0.79134
#
# Epoch 00732: val_accuracy did not improve from 0.79134
#
# Epoch 00733: val_accuracy did not improve from 0.79134
#
# Epoch 00734: val_accuracy did not improve from 0.79134
#
# Epoch 00735: val_accuracy did not improve from 0.79134
#
# Epoch 00736: val_accuracy did not improve from 0.79134
#
# Epoch 00737: val_accuracy did not improve from 0.79134
#
# Epoch 00738: val_accuracy did not improve from 0.79134
#
# Epoch 00739: val_accuracy did not improve from 0.79134
#
# Epoch 00740: val_accuracy did not improve from 0.79134
#
# Epoch 00741: val_accuracy did not improve from 0.79134
#
# Epoch 00742: val_accuracy did not improve from 0.79134
#
# Epoch 00743: val_accuracy did not improve from 0.79134
#
# Epoch 00744: val_accuracy did not improve from 0.79134
#
# Epoch 00745: val_accuracy did not improve from 0.79134
#
# Epoch 00746: val_accuracy did not improve from 0.79134
#
# Epoch 00747: val_accuracy did not improve from 0.79134
#
# Epoch 00748: val_accuracy did not improve from 0.79134
#
# Epoch 00749: val_accuracy did not improve from 0.79134
#
# Epoch 00750: val_accuracy did not improve from 0.79134
#
# Epoch 00751: val_accuracy did not improve from 0.79134
#
# Epoch 00752: val_accuracy did not improve from 0.79134
#
# Epoch 00753: val_accuracy did not improve from 0.79134
#
# Epoch 00754: val_accuracy did not improve from 0.79134
#
# Epoch 00755: val_accuracy did not improve from 0.79134
#
# Epoch 00756: val_accuracy did not improve from 0.79134
#
# Epoch 00757: val_accuracy did not improve from 0.79134
#
# Epoch 00758: val_accuracy did not improve from 0.79134
#
# Epoch 00759: val_accuracy did not improve from 0.79134
#
# Epoch 00760: val_accuracy did not improve from 0.79134
#
# Epoch 00761: val_accuracy did not improve from 0.79134
#
# Epoch 00762: val_accuracy did not improve from 0.79134
#
# Epoch 00763: val_accuracy did not improve from 0.79134
#
# Epoch 00764: val_accuracy did not improve from 0.79134
#
# Epoch 00765: val_accuracy did not improve from 0.79134
#
# Epoch 00766: val_accuracy did not improve from 0.79134
#
# Epoch 00767: val_accuracy did not improve from 0.79134
#
# Epoch 00768: val_accuracy did not improve from 0.79134
#
# Epoch 00769: val_accuracy did not improve from 0.79134
#
# Epoch 00770: val_accuracy did not improve from 0.79134
#
# Epoch 00771: val_accuracy did not improve from 0.79134
#
# Epoch 00772: val_accuracy did not improve from 0.79134
#
# Epoch 00773: val_accuracy did not improve from 0.79134
#
# Epoch 00774: val_accuracy did not improve from 0.79134
#
# Epoch 00775: val_accuracy did not improve from 0.79134
#
# Epoch 00776: val_accuracy did not improve from 0.79134
#
# Epoch 00777: val_accuracy did not improve from 0.79134
#
# Epoch 00778: val_accuracy did not improve from 0.79134
#
# Epoch 00779: val_accuracy did not improve from 0.79134
#
# Epoch 00780: val_accuracy did not improve from 0.79134
#
# Epoch 00781: val_accuracy did not improve from 0.79134
#
# Epoch 00782: val_accuracy did not improve from 0.79134
#
# Epoch 00783: val_accuracy did not improve from 0.79134
#
# Epoch 00784: val_accuracy did not improve from 0.79134
#
# Epoch 00785: val_accuracy did not improve from 0.79134
#
# Epoch 00786: val_accuracy did not improve from 0.79134
#
# Epoch 00787: val_accuracy did not improve from 0.79134
#
# Epoch 00788: val_accuracy did not improve from 0.79134
#
# Epoch 00789: val_accuracy did not improve from 0.79134
#
# Epoch 00790: val_accuracy did not improve from 0.79134
#
# Epoch 00791: val_accuracy did not improve from 0.79134
#
# Epoch 00792: val_accuracy did not improve from 0.79134
#
# Epoch 00793: val_accuracy did not improve from 0.79134
#
# Epoch 00794: val_accuracy did not improve from 0.79134
#
# Epoch 00795: val_accuracy did not improve from 0.79134
#
# Epoch 00796: val_accuracy did not improve from 0.79134
#
# Epoch 00797: val_accuracy did not improve from 0.79134
#
# Epoch 00798: val_accuracy did not improve from 0.79134
#
# Epoch 00799: val_accuracy did not improve from 0.79134
#
# Epoch 00800: val_accuracy did not improve from 0.79134
#
# Epoch 00801: val_accuracy did not improve from 0.79134
#
# Epoch 00802: val_accuracy did not improve from 0.79134
#
# Epoch 00803: val_accuracy did not improve from 0.79134
#
# Epoch 00804: val_accuracy did not improve from 0.79134
#
# Epoch 00805: val_accuracy did not improve from 0.79134
#
# Epoch 00806: val_accuracy did not improve from 0.79134
#
# Epoch 00807: val_accuracy did not improve from 0.79134
#
# Epoch 00808: val_accuracy did not improve from 0.79134
#
# Epoch 00809: val_accuracy did not improve from 0.79134
#
# Epoch 00810: val_accuracy did not improve from 0.79134
#
# Epoch 00811: val_accuracy did not improve from 0.79134
#
# Epoch 00812: val_accuracy did not improve from 0.79134
#
# Epoch 00813: val_accuracy did not improve from 0.79134
#
# Epoch 00814: val_accuracy did not improve from 0.79134
#
# Epoch 00815: val_accuracy did not improve from 0.79134
#
# Epoch 00816: val_accuracy did not improve from 0.79134
#
# Epoch 00817: val_accuracy did not improve from 0.79134
#
# Epoch 00818: val_accuracy did not improve from 0.79134
#
# Epoch 00819: val_accuracy did not improve from 0.79134
#
# Epoch 00820: val_accuracy did not improve from 0.79134
#
# Epoch 00821: val_accuracy did not improve from 0.79134
#
# Epoch 00822: val_accuracy did not improve from 0.79134
#
# Epoch 00823: val_accuracy did not improve from 0.79134
#
# Epoch 00824: val_accuracy did not improve from 0.79134
#
# Epoch 00825: val_accuracy did not improve from 0.79134
#
# Epoch 00826: val_accuracy did not improve from 0.79134
#
# Epoch 00827: val_accuracy did not improve from 0.79134
#
# Epoch 00828: val_accuracy did not improve from 0.79134
#
# Epoch 00829: val_accuracy did not improve from 0.79134
#
# Epoch 00830: val_accuracy did not improve from 0.79134
#
# Epoch 00831: val_accuracy did not improve from 0.79134
#
# Epoch 00832: val_accuracy did not improve from 0.79134
#
# Epoch 00833: val_accuracy did not improve from 0.79134
#
# Epoch 00834: val_accuracy did not improve from 0.79134
#
# Epoch 00835: val_accuracy did not improve from 0.79134
#
# Epoch 00836: val_accuracy did not improve from 0.79134
#
# Epoch 00837: val_accuracy did not improve from 0.79134
#
# Epoch 00838: val_accuracy did not improve from 0.79134
#
# Epoch 00839: val_accuracy did not improve from 0.79134
#
# Epoch 00840: val_accuracy did not improve from 0.79134
#
# Epoch 00841: val_accuracy did not improve from 0.79134
#
# Epoch 00842: val_accuracy did not improve from 0.79134
#
# Epoch 00843: val_accuracy did not improve from 0.79134
#
# Epoch 00844: val_accuracy did not improve from 0.79134
#
# Epoch 00845: val_accuracy did not improve from 0.79134
#
# Epoch 00846: val_accuracy did not improve from 0.79134
#
# Epoch 00847: val_accuracy did not improve from 0.79134
#
# Epoch 00848: val_accuracy did not improve from 0.79134
#
# Epoch 00849: val_accuracy did not improve from 0.79134
#
# Epoch 00850: val_accuracy did not improve from 0.79134
#
# Epoch 00851: val_accuracy did not improve from 0.79134
#
# Epoch 00852: val_accuracy did not improve from 0.79134
#
# Epoch 00853: val_accuracy did not improve from 0.79134
#
# Epoch 00854: val_accuracy did not improve from 0.79134
#
# Epoch 00855: val_accuracy did not improve from 0.79134
#
# Epoch 00856: val_accuracy did not improve from 0.79134
#
# Epoch 00857: val_accuracy did not improve from 0.79134
#
# Epoch 00858: val_accuracy did not improve from 0.79134
#
# Epoch 00859: val_accuracy did not improve from 0.79134
#
# Epoch 00860: val_accuracy did not improve from 0.79134
#
# Epoch 00861: val_accuracy did not improve from 0.79134
#
# Epoch 00862: val_accuracy did not improve from 0.79134
#
# Epoch 00863: val_accuracy did not improve from 0.79134
#
# Epoch 00864: val_accuracy did not improve from 0.79134
#
# Epoch 00865: val_accuracy did not improve from 0.79134
#
# Epoch 00866: val_accuracy did not improve from 0.79134
#
# Epoch 00867: val_accuracy did not improve from 0.79134
#
# Epoch 00868: val_accuracy did not improve from 0.79134
#
# Epoch 00869: val_accuracy did not improve from 0.79134
#
# Epoch 00870: val_accuracy did not improve from 0.79134
#
# Epoch 00871: val_accuracy did not improve from 0.79134
#
# Epoch 00872: val_accuracy did not improve from 0.79134
#
# Epoch 00873: val_accuracy did not improve from 0.79134
#
# Epoch 00874: val_accuracy did not improve from 0.79134
#
# Epoch 00875: val_accuracy did not improve from 0.79134
#
# Epoch 00876: val_accuracy did not improve from 0.79134
#
# Epoch 00877: val_accuracy did not improve from 0.79134
#
# Epoch 00878: val_accuracy did not improve from 0.79134
#
# Epoch 00879: val_accuracy did not improve from 0.79134
#
# Epoch 00880: val_accuracy did not improve from 0.79134
#
# Epoch 00881: val_accuracy did not improve from 0.79134
#
# Epoch 00882: val_accuracy did not improve from 0.79134
#
# Epoch 00883: val_accuracy did not improve from 0.79134
#
# Epoch 00884: val_accuracy did not improve from 0.79134
#
# Epoch 00885: val_accuracy did not improve from 0.79134
#
# Epoch 00886: val_accuracy did not improve from 0.79134
#
# Epoch 00887: val_accuracy did not improve from 0.79134
#
# Epoch 00888: val_accuracy did not improve from 0.79134
#
# Epoch 00889: val_accuracy did not improve from 0.79134
#
# Epoch 00890: val_accuracy did not improve from 0.79134
#
# Epoch 00891: val_accuracy did not improve from 0.79134
#
# Epoch 00892: val_accuracy did not improve from 0.79134
#
# Epoch 00893: val_accuracy did not improve from 0.79134
#
# Epoch 00894: val_accuracy did not improve from 0.79134
#
# Epoch 00895: val_accuracy did not improve from 0.79134
#
# Epoch 00896: val_accuracy did not improve from 0.79134
#
# Epoch 00897: val_accuracy did not improve from 0.79134
#
# Epoch 00898: val_accuracy did not improve from 0.79134
#
# Epoch 00899: val_accuracy did not improve from 0.79134
#
# Epoch 00900: val_accuracy did not improve from 0.79134
#
# Epoch 00901: val_accuracy did not improve from 0.79134
#
# Epoch 00902: val_accuracy did not improve from 0.79134
#
# Epoch 00903: val_accuracy did not improve from 0.79134
#
# Epoch 00904: val_accuracy did not improve from 0.79134
#
# Epoch 00905: val_accuracy did not improve from 0.79134
#
# Epoch 00906: val_accuracy did not improve from 0.79134
#
# Epoch 00907: val_accuracy did not improve from 0.79134
#
# Epoch 00908: val_accuracy did not improve from 0.79134
#
# Epoch 00909: val_accuracy did not improve from 0.79134
#
# Epoch 00910: val_accuracy did not improve from 0.79134
#
# Epoch 00911: val_accuracy did not improve from 0.79134
#
# Epoch 00912: val_accuracy did not improve from 0.79134
#
# Epoch 00913: val_accuracy did not improve from 0.79134
#
# Epoch 00914: val_accuracy did not improve from 0.79134
#
# Epoch 00915: val_accuracy did not improve from 0.79134
#
# Epoch 00916: val_accuracy did not improve from 0.79134
#
# Epoch 00917: val_accuracy did not improve from 0.79134
#
# Epoch 00918: val_accuracy did not improve from 0.79134
#
# Epoch 00919: val_accuracy did not improve from 0.79134
#
# Epoch 00920: val_accuracy did not improve from 0.79134
#
# Epoch 00921: val_accuracy did not improve from 0.79134
#
# Epoch 00922: val_accuracy did not improve from 0.79134
#
# Epoch 00923: val_accuracy did not improve from 0.79134
#
# Epoch 00924: val_accuracy did not improve from 0.79134
#
# Epoch 00925: val_accuracy did not improve from 0.79134
#
# Epoch 00926: val_accuracy did not improve from 0.79134
#
# Epoch 00927: val_accuracy did not improve from 0.79134
#
# Epoch 00928: val_accuracy did not improve from 0.79134
#
# Epoch 00929: val_accuracy did not improve from 0.79134
#
# Epoch 00930: val_accuracy did not improve from 0.79134
#
# Epoch 00931: val_accuracy did not improve from 0.79134
#
# Epoch 00932: val_accuracy did not improve from 0.79134
#
# Epoch 00933: val_accuracy did not improve from 0.79134
#
# Epoch 00934: val_accuracy did not improve from 0.79134
#
# Epoch 00935: val_accuracy did not improve from 0.79134
#
# Epoch 00936: val_accuracy did not improve from 0.79134
#
# Epoch 00937: val_accuracy did not improve from 0.79134
#
# Epoch 00938: val_accuracy did not improve from 0.79134
#
# Epoch 00939: val_accuracy did not improve from 0.79134
#
# Epoch 00940: val_accuracy did not improve from 0.79134
#
# Epoch 00941: val_accuracy did not improve from 0.79134
#
# Epoch 00942: val_accuracy did not improve from 0.79134
#
# Epoch 00943: val_accuracy did not improve from 0.79134
#
# Epoch 00944: val_accuracy did not improve from 0.79134
#
# Epoch 00945: val_accuracy did not improve from 0.79134
#
# Epoch 00946: val_accuracy did not improve from 0.79134
#
# Epoch 00947: val_accuracy did not improve from 0.79134
#
# Epoch 00948: val_accuracy did not improve from 0.79134
#
# Epoch 00949: val_accuracy did not improve from 0.79134
#
# Epoch 00950: val_accuracy did not improve from 0.79134
#
# Epoch 00951: val_accuracy did not improve from 0.79134
#
# Epoch 00952: val_accuracy did not improve from 0.79134
#
# Epoch 00953: val_accuracy did not improve from 0.79134
#
# Epoch 00954: val_accuracy did not improve from 0.79134
#
# Epoch 00955: val_accuracy did not improve from 0.79134
#
# Epoch 00956: val_accuracy did not improve from 0.79134
#
# Epoch 00957: val_accuracy did not improve from 0.79134
#
# Epoch 00958: val_accuracy did not improve from 0.79134
#
# Epoch 00959: val_accuracy did not improve from 0.79134
#
# Epoch 00960: val_accuracy did not improve from 0.79134
#
# Epoch 00961: val_accuracy did not improve from 0.79134
#
# Epoch 00962: val_accuracy did not improve from 0.79134
#
# Epoch 00963: val_accuracy did not improve from 0.79134
#
# Epoch 00964: val_accuracy did not improve from 0.79134
#
# Epoch 00965: val_accuracy did not improve from 0.79134
#
# Epoch 00966: val_accuracy did not improve from 0.79134
#
# Epoch 00967: val_accuracy did not improve from 0.79134
#
# Epoch 00968: val_accuracy did not improve from 0.79134
#
# Epoch 00969: val_accuracy did not improve from 0.79134
#
# Epoch 00970: val_accuracy did not improve from 0.79134
#
# Epoch 00971: val_accuracy did not improve from 0.79134
#
# Epoch 00972: val_accuracy did not improve from 0.79134
#
# Epoch 00973: val_accuracy did not improve from 0.79134
#
# Epoch 00974: val_accuracy did not improve from 0.79134
#
# Epoch 00975: val_accuracy did not improve from 0.79134
#
# Epoch 00976: val_accuracy did not improve from 0.79134
#
# Epoch 00977: val_accuracy did not improve from 0.79134
#
# Epoch 00978: val_accuracy did not improve from 0.79134
#
# Epoch 00979: val_accuracy did not improve from 0.79134
#
# Epoch 00980: val_accuracy did not improve from 0.79134
#
# Epoch 00981: val_accuracy did not improve from 0.79134
#
# Epoch 00982: val_accuracy did not improve from 0.79134
#
# Epoch 00983: val_accuracy did not improve from 0.79134
#
# Epoch 00984: val_accuracy did not improve from 0.79134
#
# Epoch 00985: val_accuracy did not improve from 0.79134
#
# Epoch 00986: val_accuracy did not improve from 0.79134
#
# Epoch 00987: val_accuracy did not improve from 0.79134
#
# Epoch 00988: val_accuracy did not improve from 0.79134
#
# Epoch 00989: val_accuracy did not improve from 0.79134
#
# Epoch 00990: val_accuracy did not improve from 0.79134
#
# Epoch 00991: val_accuracy did not improve from 0.79134
#
# Epoch 00992: val_accuracy did not improve from 0.79134
#
# Epoch 00993: val_accuracy did not improve from 0.79134
#
# Epoch 00994: val_accuracy did not improve from 0.79134
#
# Epoch 00995: val_accuracy did not improve from 0.79134
#
# Epoch 00996: val_accuracy did not improve from 0.79134
#
# Epoch 00997: val_accuracy did not improve from 0.79134
#
# Epoch 00998: val_accuracy did not improve from 0.79134
#
# Epoch 00999: val_accuracy did not improve from 0.79134
#
# Epoch 01000: val_accuracy did not improve from 0.79134
#
# Epoch 01001: val_accuracy did not improve from 0.79134
#
# Epoch 01002: val_accuracy did not improve from 0.79134
#
# Epoch 01003: val_accuracy did not improve from 0.79134
#
# Epoch 01004: val_accuracy did not improve from 0.79134
#
# Epoch 01005: val_accuracy did not improve from 0.79134
#
# Epoch 01006: val_accuracy did not improve from 0.79134
#
# Epoch 01007: val_accuracy did not improve from 0.79134
#
# Epoch 01008: val_accuracy did not improve from 0.79134
#
# Epoch 01009: val_accuracy did not improve from 0.79134
#
# Epoch 01010: val_accuracy did not improve from 0.79134
#
# Epoch 01011: val_accuracy did not improve from 0.79134
#
# Epoch 01012: val_accuracy did not improve from 0.79134
#
# Epoch 01013: val_accuracy did not improve from 0.79134
#
# Epoch 01014: val_accuracy did not improve from 0.79134
#
# Epoch 01015: val_accuracy did not improve from 0.79134
#
# Epoch 01016: val_accuracy did not improve from 0.79134
#
# Epoch 01017: val_accuracy did not improve from 0.79134
#
# Epoch 01018: val_accuracy did not improve from 0.79134
#
# Epoch 01019: val_accuracy did not improve from 0.79134
#
# Epoch 01020: val_accuracy did not improve from 0.79134
#
# Epoch 01021: val_accuracy did not improve from 0.79134
#
# Epoch 01022: val_accuracy did not improve from 0.79134
#
# Epoch 01023: val_accuracy did not improve from 0.79134
#
# Epoch 01024: val_accuracy did not improve from 0.79134
#
# Epoch 01025: val_accuracy did not improve from 0.79134
#
# Epoch 01026: val_accuracy did not improve from 0.79134
#
# Epoch 01027: val_accuracy did not improve from 0.79134
#
# Epoch 01028: val_accuracy did not improve from 0.79134
#
# Epoch 01029: val_accuracy did not improve from 0.79134
#
# Epoch 01030: val_accuracy did not improve from 0.79134
#
# Epoch 01031: val_accuracy did not improve from 0.79134
#
# Epoch 01032: val_accuracy did not improve from 0.79134
#
# Epoch 01033: val_accuracy did not improve from 0.79134
#
# Epoch 01034: val_accuracy did not improve from 0.79134
#
# Epoch 01035: val_accuracy did not improve from 0.79134
#
# Epoch 01036: val_accuracy did not improve from 0.79134
#
# Epoch 01037: val_accuracy did not improve from 0.79134
#
# Epoch 01038: val_accuracy did not improve from 0.79134
#
# Epoch 01039: val_accuracy did not improve from 0.79134
#
# Epoch 01040: val_accuracy did not improve from 0.79134
#
# Epoch 01041: val_accuracy did not improve from 0.79134
#
# Epoch 01042: val_accuracy did not improve from 0.79134
#
# Epoch 01043: val_accuracy did not improve from 0.79134
#
# Epoch 01044: val_accuracy did not improve from 0.79134
#
# Epoch 01045: val_accuracy did not improve from 0.79134
#
# Epoch 01046: val_accuracy did not improve from 0.79134
#
# Epoch 01047: val_accuracy did not improve from 0.79134
#
# Epoch 01048: val_accuracy did not improve from 0.79134
#
# Epoch 01049: val_accuracy did not improve from 0.79134
#
# Epoch 01050: val_accuracy did not improve from 0.79134

# %% [markdown]
# You should see the weight file in your local directory.
#
# `weights.best.hdf5`

# %% [markdown]
# ## Loading a Saved Neural Network Model

# %% [markdown]
# Now that you have seen how to checkpoint your deep learning models during training, you need to review how to load and use a checkpointed model. The checkpoint only includes the model weights. It assumes you know the network structure. This too can be serialized to file in JSON or YAML format. In the example below, the model structure is known, and the best weights are loaded from the previous experiment, stored in the working directory in the `weights.best.hdf5` file. The model is then used to make predictions on the entire dataset.

# %%
import tensorflow as tf

# MLP for Pima Indians Dataset Serialize to JSON and HDF5
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import numpy

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# create model
model = Sequential()
model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

# %%
# load weights
model.load_weights("weights.best.hdf5")

# Compile model (required to make predictions)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print("Created model and loaded weights from file")

# load pima indians dataset
dataset = numpy.loadtxt(DATASET, delimiter=",")

# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# Out:
# Created model and loaded weights from file

# %% [markdown]
# Running the example produces the following output:

# %%
# estimate accuracy on whole dataset using loaded weights
scores = model.evaluate(X, Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 76.43%

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lesson, you have discovered the importance of checkpointing deep learning models for long training runs. You learned:
#
# * How to use Keras to checkpoint each time an improvement to the model is observed.
# * How to only checkpoint the very best model observed during training.
# * How to load a checkpointed model from a file and use it later to make predictions.
